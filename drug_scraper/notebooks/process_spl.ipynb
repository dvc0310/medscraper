# %%
import spacy
import scispacy
from scispacy.linking import EntityLinker
import json
import numpy as np
from drug_utils import DataHandler
from tqdm import tqdm
import re

# %%
nlp = spacy.load("en_core_sci_sm")
nlp.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})

# Obtain the linker from the pipeline
linker = nlp.get_pipe("scispacy_linker")
# Out:
# c:\Users\sjchu\.pyenv\pyenv-win\versions\3.9.6\lib\site-packages\spacy\language.py:2141: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]

# %%
# Load the JSON data
with open("./jsons/processed_data3.json", 'r', encoding='utf-8') as file:
    drugs_data = json.load(file)

# %%
def process_drug(drug, nlp, linker, semantic_type_to_category):
    categorized_ingredients = {}
    if "spl_product_data_elements" not in drug.keys():
        return []

    doc = nlp(uses_text)
    # Process each paragraph in the 'side_effects' list for this drug
    for ent in doc.ents:
            kb_ents = ent._.kb_ents
            if kb_ents:
                cui = kb_ents[0][0]
                umls_entity = linker.kb.cui_to_entity[cui]

                for st in umls_entity.types:
                    if st in semantic_type_to_category:
                        category = semantic_type_to_category[st]
                        if category not in categorized_ingredients:
                            categorized_ingredients[category] = []
                        categorized_ingredients[category].append(umls_entity.canonical_name)

    # Deduplicate ingredients in each category
    for category in categorized_ingredients:
        categorized_ingredients[category] = list(set(categorized_ingredients[category]))

    return categorized_ingredients

# %%
def process_drug(drug, nlp, linker, semantic_type_to_category):
    # Dictionary to hold ingredients and their categories
    ingredient_categories = {}

    if "spl_product_data_elements" not in drug.keys():
        return {}

    for uses_text in drug["spl_product_data_elements"]:
        doc = nlp(uses_text)

        for ent in doc.ents:
            kb_ents = ent._.kb_ents
            if kb_ents:
                cui = kb_ents[0][0]
                umls_entity = linker.kb.cui_to_entity[cui]

                # Loop through the semantic types of the entity
                for st in umls_entity.types:
                    # Check if the semantic type is in your mapping
                    if st in semantic_type_to_category:
                        category = semantic_type_to_category[st]

                        # If the ingredient is not already in the dictionary, add it
                        if umls_entity.canonical_name not in ingredient_categories:
                            ingredient_categories[umls_entity.canonical_name] = []

                        # Add the category to the ingredient
                        if category not in ingredient_categories[umls_entity.canonical_name]:
                            ingredient_categories[umls_entity.canonical_name].append(category)

    return ingredient_categories

# %%
def process_ingredients(drugs_data, nlp, linker, semantic_type_to_category):
    # Initialize dictionary for drug uses
    
    # Iterate over each drug in the data
    for drug in tqdm(drugs_data, desc="Processing Drugs"):
        ingredients = process_drug(drug, nlp, linker, semantic_type_to_category)
        drug["ingredients"] = ingredients

    return drugs_data

# %%
semantic_type_to_category = {
        "T197": "Immunologic Factors",
        "T121": "Pharmacologic Substances",
        "T109": "Organic Chemicals",
        "T123": "Biologically Active Substances",
        "T195": "Antibiotics",
        "T168": "Food",
        "T125": "Hormone",
        "T110": "Eicosanoids",
        "T127": "Vitamins",
        "T114": "Nucleic Acids",
        "T103": "Chemical",
        "T115": "Organophosphorus Compounds",
        "T116": "Amino Acid, Peptide, or Protein",
        "T088": "Carbohydrate Sequence",
        "T002" : "Plant"
}

# %%
drugs_data = process_ingredients(drugs_data, nlp, linker, semantic_type_to_category)
filtered_drugs_data = [drug for drug in drugs_data if drug['status'] != 'Unknown']
# Out:
# Processing Drugs:   0%|          | 0/7878 [00:00<?, ?it/s]
# Processing Drugs: 100%|██████████| 7878/7878 [12:54<00:00, 10.17it/s]

# %%
drugs_data
# Out:
# [{'name': 'Azulfidine',
#   'alternative_names': ['azulfidine', 'sulfasalazine'],
#   'drug_classes': ['5-aminosalicylates', 'Antirheumatics'],
#   'uses': ['Rheumatoid Arthritis', 'Arthritis', 'Ulcerative Colitis'],
#   'status': 'Prescription only',
#   'generic_name': 'sulfasalazine',
#   'spl_product_data_elements': ['Azulfidine EN-tabs Sulfasalazine SULFASALAZINE SULFASALAZINE WHITE WAX CARNAUBA WAX CELLACEFATE MAGNESIUM STEARATE POLYETHYLENE GLYCOL 20000 POVIDONE, UNSPECIFIED PROPYLENE GLYCOL GLYCERYL STEARATE SE SILICON DIOXIDE STARCH, CORN TALC Gold elliptical convex 102;KPh'],
#   'ingredients': ['Azulfidine',
#    'starch',
#    'gold',
#    'Stearates',
#    'povidone',
#    'sulfasalazine']},
#  {'name': 'Abstral',
#   'alternative_names': ['fentanyl', 'abstral'],
#   'drug_classes': ['Opioids (narcotic analgesics)'],
#   'uses': ['Cancer Pain'],
#   'status': 'Discontinued',
#   'generic_name': 'fentanyl',
#   'spl_product_data_elements': ['Fentanyl Citrate Fentanyl Citrate Fentanyl Citrate Fentanyl Hydrochloric Acid Sodium Hydroxide Water Fentanyl Citrate Fentanyl Citrate Fentanyl Citrate Fentanyl Hydrochloric Acid Sodium Hydroxide Water'],
#   'ingredients': ['fentanyl citrate',
#    'fentanyl',
#    'fentanyl hydrochloride',
#    'Citrates']},
#  {'name': 'Aczone',
#   'alternative_names': ['dapsone-topical', 'dapsone topical', 'aczone'],
#   'drug_classes': ['Topical acne agents'],
#   'uses': ['Hypersensitivity', 'Acne Vulgaris'],
#   'status': 'Prescription only',
#   'generic_name': 'dapsone-topical',
#   'spl_product_data_elements': ['Aczone dapsone DAPSONE DAPSONE DIETHYLENE GLYCOL MONOETHYL ETHER METHYLPARABEN SODIUM ACRYLOYLDIMETHYLTAURATE-ACRYLAMIDE COPOLYMER (1:1; 90000-150000 MPA.S) ISOHEXADECANE POLYSORBATE 80 WATER off-white to yellow'],
#   'ingredients': ['water', 'polysorbates']},
#  {'name': 'Adzynma',
#   'alternative_names': ['adzynma', 'adamts13, recombinant-krhn'],
#   'drug_classes': [],
#   'uses': ['Intravenous infusion procedures',
#    'Headache',
#    'Thrombus',
#    'Congenital Thrombotic Thrombocytopenic Purpura',
#    'Digital Arthropathy-Brachydactyly, Familial',
#    'Anemia, Hemolytic',
#    'Abdominal Pain',
#    'Infusion procedures',
#    'Blood Coagulation Disorders'],
#   'status': 'Prescription only',
#   'generic_name': 'adamts13, recombinant-krhn',
#   'spl_product_data_elements': ['ADZYNMA Apadamtase Alfa ADZYNMA Apadamtase Alfa Apadamtase Alfa Apadamtase Alfa Sodium Chloride Calcium Chloride Histidine Mannitol Sucrose Polysorbate 80 Sterile Water Water WATER ADZYNMA Apadamtase Alfa ADZYNMA Apadamtase Alfa Apadamtase Alfa Apadamtase Alfa Sodium Chloride Calcium Chloride Histidine Mannitol Sucrose Polysorbate 80 Sterile Water Water WATER'],
#   'ingredients': ['Apadamtase alfa',
#    'calcium chloride',
#    'histidine',
#    'water',
#    'sterile water']},
#  {'name': 'Adzenys XR-ODT',
#   'alternative_names': ['amphetamine', 'adzenys xr-odt'],
#   'drug_classes': ['CNS stimulants'],
#   'uses': ['Narcolepsy',
#    'Obesity',
#    'Attention deficit hyperactivity disorder',
#    'Therapeutic procedure'],
#   'status': 'Prescription only',
#   'generic_name': 'amphetamine',
#   'spl_product_data_elements': ['Adzenys XR-ODT Amphetamine MANNITOL CROSPOVIDONE (15 MPA.S AT 5%) MICROCRYSTALLINE CELLULOSE METHACRYLIC ACID SODIUM POLYSTYRENE SULFONATE CITRIC ACID MONOHYDRATE FRUCTOSE SILICON DIOXIDE TRIETHYL CITRATE SUCRALOSE MAGNESIUM STEARATE POLYETHYLENE GLYCOL, UNSPECIFIED AMPHETAMINE AMPHETAMINE A6 Adzenys XR-ODT Amphetamine MANNITOL CROSPOVIDONE (15 MPA.S AT 5%) MICROCRYSTALLINE CELLULOSE METHACRYLIC ACID SODIUM POLYSTYRENE SULFONATE CITRIC ACID MONOHYDRATE FRUCTOSE SILICON DIOXIDE TRIETHYL CITRATE SUCRALOSE MAGNESIUM STEARATE POLYETHYLENE GLYCOL, UNSPECIFIED AMPHETAMINE AMPHETAMINE orange to light orange mottled A1 Adzenys XR-ODT Amphetamine MANNITOL CROSPOVIDONE (15 MPA.S AT 5%) MICROCRYSTALLINE CELLULOSE METHACRYLIC ACID SODIUM POLYSTYRENE SULFONATE CITRIC ACID MONOHYDRATE FRUCTOSE SILICON DIOXIDE TRIETHYL CITRATE SUCRALOSE MAGNESIUM STEARATE POLYETHYLENE GLYCOL, UNSPECIFIED AMPHETAMINE AMPHETAMINE A2 Adzenys XR-ODT Amphetamine MANNITOL CROSPOVIDONE (15 MPA.S AT 5%) MICROCRYSTALLINE CELLULOSE METHACRYLIC ACID SODIUM POLYSTYRENE SULFONATE CITRIC ACID MONOHYDRATE FRUCTOSE SILICON DIOXIDE TRIETHYL CITRATE SUCRALOSE MAGNESIUM STEARATE POLYETHYLENE GLYCOL, UNSPECIFIED AMPHETAMINE AMPHETAMINE A3 Adzenys XR-ODT Amphetamine MANNITOL CROSPOVIDONE (15 MPA.S AT 5%) MICROCRYSTALLINE CELLULOSE METHACRYLIC ACID SODIUM POLYSTYRENE SULFONATE CITRIC ACID MONOHYDRATE FRUCTOSE SILICON DIOXIDE TRIETHYL CITRATE SUCRALOSE MAGNESIUM STEARATE POLYETHYLENE GLYCOL, UNSPECIFIED AMPHETAMINE AMPHETAMINE A4 Adzenys XR-ODT Amphetamine MANNITOL CROSPOVIDONE (15 MPA.S AT 5%) MICROCRYSTALLINE CELLULOSE METHACRYLIC ACID SODIUM POLYSTYRENE SULFONATE CITRIC ACID MONOHYDRATE FRUCTOSE SILICON DIOXIDE TRIETHYL CITRATE SUCRALOSE MAGNESIUM STEARATE POLYETHYLENE GLYCOL, UNSPECIFIED AMPHETAMINE AMPHETAMINE A5'],
#   'ingredients': ['Glycol',
#    'magnesium citrate',
#    'amphetamine',
#    'Stearates',
#    'Adzenys']},
#  {'name': 'AfterPill',
#   'alternative_names': ['levonorgestrel',
#    'afterpill',
#    'levonorgestrel emergency contraceptive'],
#   'drug_classes': ['Contraceptives'],
#   'uses': ['Contraceptive methods'],
#   'status': 'Over the counter',
#   'generic_name': 'levonorgestrel',
#   'spl_product_data_elements': ['AfterPill levonorgestrel LEVONORGESTREL LEVONORGESTREL LACTOSE MONOHYDRATE MAGNESIUM STEARATE POVIDONE K30 SILICON DIOXIDE STARCH, CORN white to off white round biconvex LU;S25'],
#   'ingredients': ['starch', 'levonorgestrel']},
#  {'name': 'Afstyla',
#   'alternative_names': ['afstyla (recombinant)',
#    'antihemophilic-factor',
#    'antihemophilic factor (recombinant)'],
#   'drug_classes': ['Miscellaneous coagulation modifiers'],
#   'uses': ['von Willebrand Disease', 'Hemorrhage', 'Hemophilia A'],
#   'status': 'Prescription only',
#   'generic_name': 'antihemophilic-factor',
#   'spl_product_data_elements': ['ALTUVIIIO Antihemophilic Factor (Recombinant), Fc-VWF-XTEN Fusion Protein-ehtl ALTUVIIIO efanesoctocog alfa EFANESOCTOCOG ALFA EFANESOCTOCOG ALFA ARGININE HYDROCHLORIDE CALCIUM CHLORIDE HISTIDINE POLYSORBATE 80 SUCROSE Sterile Water Sterile Water WATER ALTUVIIIO Antihemophilic Factor (Recombinant), Fc-VWF-XTEN Fusion Protein-ehtl ALTUVIIIO efanesoctocog alfa EFANESOCTOCOG ALFA EFANESOCTOCOG ALFA ARGININE HYDROCHLORIDE CALCIUM CHLORIDE HISTIDINE POLYSORBATE 80 SUCROSE Sterile Water Sterile Water WATER ALTUVIIIO Antihemophilic Factor (Recombinant), Fc-VWF-XTEN Fusion Protein-ehtl ALTUVIIIO efanesoctocog alfa EFANESOCTOCOG ALFA EFANESOCTOCOG ALFA ARGININE HYDROCHLORIDE CALCIUM CHLORIDE HISTIDINE POLYSORBATE 80 SUCROSE Sterile Water Sterile Water WATER ALTUVIIIO Antihemophilic Factor (Recombinant), Fc-VWF-XTEN Fusion Protein-ehtl ALTUVIIIO efanesoctocog alfa EFANESOCTOCOG ALFA EFANESOCTOCOG ALFA ARGININE HYDROCHLORIDE CALCIUM CHLORIDE HISTIDINE POLYSORBATE 80 SUCROSE Sterile Water Sterile Water WATER ALTUVIIIO Antihemophilic Factor (Recombinant), Fc-VWF-XTEN Fusion Protein-ehtl ALTUVIIIO efanesoctocog alfa EFANESOCTOCOG ALFA EFANESOCTOCOG ALFA ARGININE HYDROCHLORIDE CALCIUM CHLORIDE HISTIDINE POLYSORBATE 80 SUCROSE Sterile Water Sterile Water WATER ALTUVIIIO Antihemophilic Factor (Recombinant), Fc-VWF-XTEN Fusion Protein-ehtl ALTUVIIIO efanesoctocog alfa EFANESOCTOCOG ALFA EFANESOCTOCOG ALFA ARGININE HYDROCHLORIDE CALCIUM CHLORIDE HISTIDINE POLYSORBATE 80 SUCROSE Sterile Water Sterile Water WATER'],
#   'ingredients': ['calcium chloride',
#    'sucrose',
#    'polysorbates',
#    'water',
#    'Efanesoctocog alfa',
#    'sterile water']},
#  {'name': 'Afrin Severe Congestion NoDrip',
#   'alternative_names': ['afrin severe congestion nodrip',
#    'oxymetazoline-nasal',
#    'oxymetazoline nasal'],
#   'drug_classes': ['Nasal antihistamines and decongestants'],
#   'uses': ['Hypersensitivity', 'Nasal congestion (finding)'],
#   'status': 'Over the counter',
#   'generic_name': 'oxymetazoline-nasal',
#   'spl_product_data_elements': ['Equate Oxymetazoline HCL WATER POVIDONE PROPYLENE GLYCOL SODIUM PHOSPHATE, DIBASIC SODIUM PHOSPHATE, MONOBASIC POLYETHYLENE GLYCOL, UNSPECIFIED ALOE VERA LEAF BENZYL ALCOHOL BENZALKONIUM CHLORIDE EDETATE DISODIUM OXYMETAZOLINE HYDROCHLORIDE OXYMETAZOLINE'],
#   'ingredients': ['Glycol', 'oxymetazoline hydrochloride']},
#  {'name': 'Airsupra',
#   'alternative_names': ['airsupra (inhalation)',
#    'albuterol-budesonide',
#    'albuterol and budesonide'],
#   'drug_classes': ['Antiasthmatic combinations'],
#   'uses': ['Asthma'],
#   'status': 'Prescription only',
#   'generic_name': 'albuterol-budesonide',
#   'spl_product_data_elements': ['AIRSUPRA Albuterol sulfate and budesonide ALBUTEROL SULFATE ALBUTEROL BUDESONIDE BUDESONIDE 1,2-DISTEAROYL-SN-GLYCERO-3-PHOSPHOCHOLINE CALCIUM CHLORIDE NORFLURANE'],
#   'ingredients': ['albuterol sulfate', 'calcium chloride']},
#  {'name': 'Airsupra',
#   'alternative_names': ['albuterol and budesonide',
#    'albuterol-budesonide',
#    'airsupra'],
#   'drug_classes': ['Antiasthmatic combinations'],
#   'uses': ['Dyspnea', 'Inflammation'],
#   'status': 'Prescription only',
#   'generic_name': 'albuterol-budesonide',
#   'spl_product_data_elements': ['AIRSUPRA Albuterol sulfate and budesonide ALBUTEROL SULFATE ALBUTEROL BUDESONIDE BUDESONIDE 1,2-DISTEAROYL-SN-GLYCERO-3-PHOSPHOCHOLINE CALCIUM CHLORIDE NORFLURANE'],
#   'ingredients': ['albuterol sulfate', 'calcium chloride']},
#  {'name': 'Akynzeo for',
#   'alternative_names': ['akynzeo for (injection)',
#    'miscellaneous antiemetics',
#    'fosnetupitant-palonosetron'],
#   'drug_classes': ['Miscellaneous antiemetics'],
#   'uses': ['Nausea', 'Pharmacotherapy', 'Vomiting'],
#   'status': 'Prescription only',
#   'generic_name': 'fosnetupitant-palonosetron',
#   'spl_product_data_elements': ['Palonosetron Hydrochloride Palonosetron Hydrochloride PALONOSETRON HYDROCHLORIDE PALONOSETRON MANNITOL EDETATE DISODIUM CITRIC ACID MONOHYDRATE SODIUM CITRATE, UNSPECIFIED FORM WATER HYDROCHLORIC ACID SODIUM HYDROXIDE'],
#   'ingredients': ['water',
#    'citric acid',
#    'palonosetron hydrochloride',
#    'Citrates']},
#  {'name': 'Alyq',
#   'alternative_names': ['alyq', 'tadalafil'],
#   'drug_classes': ['Agents for pulmonary hypertension'],
#   'uses': ['Erectile dysfunction',
#    'Benign Prostatic Hyperplasia',
#    'Pulmonary arterial hypertension'],
#   'status': 'Prescription only',
#   'generic_name': 'tadalafil',
#   'spl_product_data_elements': ['ALYQ Tadalafil TADALAFIL TADALAFIL CROSCARMELLOSE SODIUM FERRIC OXIDE RED FERRIC OXIDE YELLOW LACTOSE MONOHYDRATE MICROCRYSTALLINE CELLULOSE POLYETHYLENE GLYCOL 3350 POLYVINYL ALCOHOL, UNSPECIFIED POVIDONE K30 SODIUM LAURYL SULFATE SODIUM STARCH GLYCOLATE TYPE A POTATO SODIUM STEARYL FUMARATE TALC TITANIUM DIOXIDE TEVA;3334'],
#   'ingredients': ['tadalafil',
#    'sodium dodecyl sulfate',
#    'dioxide',
#    'fumarate',
#    'ethanol',
#    'talc',
#    'Polyvinyls',
#    'povidone',
#    'Alyq']},
#  {'name': 'Amzeeq',
#   'alternative_names': ['minocycline topical',
#    'amzeeq',
#    'minocycline-topical'],
#   'drug_classes': [],
#   'uses': ['Cellulitis', 'Acne Vulgaris'],
#   'status': 'Prescription only',
#   'generic_name': 'minocycline-topical',
#   'spl_product_data_elements': ['AMZEEQ Minocycline MINOCYCLINE HYDROCHLORIDE MINOCYCLINE HYDROGENATED SOYBEAN OIL COCONUT OIL LIGHT MINERAL OIL CYCLOMETHICONE CETOSTEARYL ALCOHOL STEARIC ACID MYRISTYL ALCOHOL HYDROGENATED CASTOR OIL WHITE WAX STEARYL ALCOHOL DOCOSANOL BUTANE ISOBUTANE PROPANE'],
#   'ingredients': ['castor oil',
#    'ethanol',
#    'Amzeeq',
#    'Oils',
#    'docosanol',
#    'minocycline hydrochloride',
#    'cyclomethicone',
#    'propane',
#    'minocycline']},
#  {'name': 'Anzemet',
#   'alternative_names': ['dolasetron', 'anzemet'],
#   'drug_classes': ['5HT3 receptor antagonists'],
#   'uses': ['Nausea',
#    'Cancer Therapeutic Procedure',
#    'Pharmacotherapy',
#    'Vomiting'],
#   'status': 'Discontinued',
#   'generic_name': 'dolasetron',
#   'ingredients': []},
#  {'name': 'Anusol-HC',
#   'alternative_names': ['anusol-hc (cream, suppository)',
#    'hydrocortisone rectal (cream, suppository)',
#    'hydrocortisone-topical'],
#   'drug_classes': ['Topical steroids'],
#   'uses': ['Pruritus', 'Edema', 'Hemorrhoids', 'Ulcerative Colitis'],
#   'status': 'Prescription only',
#   'generic_name': 'hydrocortisone-topical',
#   'spl_product_data_elements': ['Anusol HC hydrocortisone HYDROCORTISONE HYDROCORTISONE BENZYL ALCOHOL PETROLATUM STEARYL ALCOHOL PROPYLENE GLYCOL ISOPROPYL MYRISTATE POLYOXYL 40 STEARATE CARBOMER HOMOPOLYMER TYPE B (ALLYL SUCROSE CROSSLINKED) SODIUM LAURYL SULFATE EDETATE DISODIUM SODIUM HYDROXIDE WATER'],
#   'ingredients': ['carbomer',
#    'isopropyl alcohol',
#    'hydrocortisone',
#    'water',
#    'Stearates']},
#  {'name': 'Aptivus',
#   'alternative_names': ['tipranavir', 'aptivus'],
#   'drug_classes': ['Protease inhibitors'],
#   'uses': ['Acquired Immunodeficiency Syndrome'],
#   'status': 'Prescription only',
#   'generic_name': 'tipranavir',
#   'spl_product_data_elements': ['Aptivus tipranavir TIPRANAVIR TIPRANAVIR oval TPV;250 Aptivus tipranavir TIPRANAVIR TIPRANAVIR Butter Toffee'],
#   'ingredients': ['tipranavir']},
#  {'name': 'Aquoral',
#   'alternative_names': ['aquoral', 'saliva substitutes'],
#   'drug_classes': ['Mouth and throat products'],
#   'uses': ['Pain',
#    'Therapeutic radiology procedure',
#    'Discomfort',
#    'Pharmacotherapy'],
#   'status': 'Rx and/or OTC',
#   'generic_name': 'saliva substitutes',
#   'ingredients': []},
#  {'name': 'Aquatab DM',
#   'alternative_names': ['aquatab dm',
#    'dextromethorphan-guaifenesin',
#    'dextromethorphan and guaifenesin'],
#   'drug_classes': ['Upper respiratory combinations'],
#   'uses': ['Common Cold',
#    'Coughing',
#    'Hypersensitivity',
#    'Pulmonary congestion'],
#   'status': 'Rx and/or OTC',
#   'generic_name': 'dextromethorphan-guaifenesin',
#   'spl_product_data_elements': ['Tussin CF Non Drowsy Multi Symptom Dextromethorphan HBr, Guaifenesin, Phenylephrine HCl DEXTROMETHORPHAN HYDROBROMIDE DEXTROMETHORPHAN GUAIFENESIN GUAIFENESIN PHENYLEPHRINE HYDROCHLORIDE PHENYLEPHRINE ANHYDROUS CITRIC ACID GLYCERIN PROPYLENE GLYCOL WATER SODIUM BENZOATE FD&C RED NO. 40 LACTIC ACID MENTHOL SORBITOL SUCRALOSE'],
#   'ingredients': ['phenylephrine hydrochloride',
#    'dextromethorphan',
#    'Tussin CF',
#    'guaifenesin',
#    'citric acid',
#    'nitric oxide',
#    'erythrosine',
#    'scopolamine hydrobromide',
#    'guaifenesin / phenylephrine',
#    'Benzoates']},
#  {'name': 'Aquatab D',
#   'alternative_names': ['aquatab d',
#    'guaifenesin-phenylephrine',
#    'guaifenesin and phenylephrine'],
#   'drug_classes': ['Upper respiratory combinations'],
#   'uses': ['Sinus pain',
#    'Rhinorrhea',
#    'Excessive tearing',
#    'Common Cold',
#    'Sneezing',
#    'Coughing',
#    'Hay fever',
#    'Nasal congestion (finding)',
#    'Pruritus',
#    'Hypersensitivity',
#    'Symptoms',
#    'Pulmonary congestion'],
#   'status': 'Rx and/or OTC',
#   'generic_name': 'guaifenesin-phenylephrine',
#   'spl_product_data_elements': ['Tussin CF Non Drowsy Multi Symptom Dextromethorphan HBr, Guaifenesin, Phenylephrine HCl DEXTROMETHORPHAN HYDROBROMIDE DEXTROMETHORPHAN GUAIFENESIN GUAIFENESIN PHENYLEPHRINE HYDROCHLORIDE PHENYLEPHRINE ANHYDROUS CITRIC ACID GLYCERIN PROPYLENE GLYCOL WATER SODIUM BENZOATE FD&C RED NO. 40 LACTIC ACID MENTHOL SORBITOL SUCRALOSE'],
#   'ingredients': ['phenylephrine hydrochloride',
#    'dextromethorphan',
#    'Tussin CF',
#    'guaifenesin',
#    'citric acid',
#    'nitric oxide',
#    'erythrosine',
#    'scopolamine hydrobromide',
#    'guaifenesin / phenylephrine',
#    'Benzoates']},
#  {'name': 'Aquasol A',
#   'alternative_names': ['vitamin a', 'vitamin-a', 'aquasol a'],
#   'drug_classes': ['Vitamins'],
#   'uses': ['Prophylactic treatment',
#    'Retinitis Pigmentosa',
#    'Malnutrition',
#    'Disorder of eye',
#    'Cataract',
#    'Diarrhea',
#    'Tissue damage',
#    'Disease Progression'],
#   'status': 'Rx and/or OTC',
#   'generic_name': 'vitamin-a',
#   'spl_product_data_elements': ['AQUASOL A VITAMIN A PALMITATE VITAMIN A PALMITATE RETINOL CHLOROBUTANOL POLYSORBATE 80 CITRIC ACID MONOHYDRATE SODIUM HYDROXIDE'],
#   'ingredients': ['chlorobutanol',
#    'vitamin A palmitate',
#    'Aquasol A',
#    'citric acid',
#    'Vitamins',
#    'polysorbates']},
#  {'name': 'Aquaphor Itch Relief Maximum Strength',
#   'alternative_names': ['hydrocortisone topical',
#    'hydrocortisone-topical',
#    'aquaphor itch relief maximum strength'],
#   'drug_classes': ['Topical steroids'],
#   'uses': ['Pruritus', 'Dermatologic disorders', 'Inflammation'],
#   'status': 'Over the counter',
#   'generic_name': 'hydrocortisone-topical',
#   'spl_product_data_elements': ['anti itch Hydrocortisone HYDROCORTISONE HYDROCORTISONE ALOE VERA LEAF POLYOXYL 20 CETOSTEARYL ETHER CETOSTEARYL ALCOHOL CETYL PALMITATE GLYCERIN ISOPROPYL MYRISTATE METHYLPARABEN WATER ISOSTEARYL NEOPENTANOATE'],
#   'ingredients': ['hydrocortisone',
#    'Anti-Itch',
#    'water',
#    'Valerates',
#    'cetyl alcohol']},
#  {'name': 'Aquaphor Itch Relief',
#   'alternative_names': ['aquaphor itch relief',
#    'hydrocortisone topical',
#    'hydrocortisone-topical'],
#   'drug_classes': ['Topical steroids'],
#   'uses': ['Pruritus', 'Dermatologic disorders', 'Inflammation'],
#   'status': 'Over the counter',
#   'generic_name': 'hydrocortisone-topical',
#   'spl_product_data_elements': ['Aquaphor Itch Relief Hydrocortisone HYDROCORTISONE HYDROCORTISONE 3-((L-MENTHYL)OXY)PROPANE-1,2-DIOL MINERAL OIL CERESIN LANOLIN ALCOHOLS GLYCERIN PANTHENOL LEVOMENOL PETROLATUM'],
#   'ingredients': ['Aquaphor', 'hydrocortisone', 'petrolatum', 'Alcohols']},
#  {'name': 'Aquaphor Healing',
#   'alternative_names': ['petrolatum topical', 'aquaphor healing'],
#   'drug_classes': ['Topical emollients'],
#   'uses': ['Flatulence',
#    'Burn injury',
#    'Scraping',
#    'Diaper Rash',
#    'Eczema',
#    'Fecal Incontinence',
#    'Incised wound'],
#   'status': 'Over the counter',
#   'generic_name': 'petrolatum topical',
#   'spl_product_data_elements': ['Aquaphor Healing Petrolatum CERESIN LANOLIN ALCOHOLS GLYCERIN PANTHENOL LEVOMENOL PETROLATUM PETROLATUM MINERAL OIL'],
#   'ingredients': ['Oils', 'Aquaphor Healing']},
#  {'name': 'Aquaphilic with Urea',
#   'alternative_names': ['urea topical', 'aquaphilic with urea'],
#   'drug_classes': ['Topical emollients'],
#   'uses': ['Dermatologic disorders',
#    'Keratosis',
#    'Eczema',
#    'Psoriasis',
#    'Dry skin'],
#   'status': 'Rx and/or OTC',
#   'generic_name': 'urea topical',
#   'ingredients': []},
#  {'name': 'Aquanil HC',
#   'alternative_names': ['aquanil hc',
#    'hydrocortisone topical',
#    'hydrocortisone-topical'],
#   'drug_classes': ['Topical steroids'],
#   'uses': ['Pruritus', 'Dermatologic disorders', 'Inflammation'],
#   'status': 'Over the counter',
#   'generic_name': 'hydrocortisone-topical',
#   'spl_product_data_elements': ['Aquanil HC Hydrocortisone HYDROCORTISONE HYDROCORTISONE BENZYL ALCOHOL WATER SODIUM LAURYL SULFATE XANTHAN GUM GLYCERIN CETYL ALCOHOL STEARYL ALCOHOL'],
#   'ingredients': ['hydrocortisone', 'stearyl alcohol', 'ethanol']},
#  {'name': 'Aqua-Ban',
#   'alternative_names': ['aqua-ban', 'pamabrom'],
#   'drug_classes': ['Miscellaneous diuretics'],
#   'uses': ['Edema'],
#   'status': 'Over the counter',
#   'generic_name': 'pamabrom',
#   'spl_product_data_elements': ['Menstrual Pain Relief Maximum Strength Acetaminophen, Pamabrom, Pyrilamine Maleate ACETAMINOPHEN ACETAMINOPHEN PAMABROM BROMOTHEOPHYLLINE PYRILAMINE MALEATE PYRILAMINE STARCH, CORN CROSCARMELLOSE SODIUM CROSPOVIDONE FD&C BLUE NO. 2--ALUMINUM LAKE FD&C RED NO. 40 MAGNESIUM STEARATE MICROCRYSTALLINE CELLULOSE POLYETHYLENE GLYCOL, UNSPECIFIED POLYVINYL ALCOHOL, UNSPECIFIED POVIDONE, UNSPECIFIED SHELLAC SILICON DIOXIDE STEARIC ACID TALC TITANIUM DIOXIDE 44;679'],
#   'ingredients': ['erythrosine',
#    'Polyvinyls',
#    'starch',
#    'dioxide',
#    'stearic acid',
#    'nitric oxide',
#    'povidone',
#    'microcrystalline',
#    'acetaminophen',
#    'ethanol',
#    'carboxymethylcellulose sodium',
#    'magnesium',
#    'Glycol',
#    'shellac',
#    'pyrilamine',
#    'maleate',
#    'polyethylenes',
#    'pamabrom',
#    'Stearates']},
#  {'name': 'Aqua Care',
#   'alternative_names': ['urea topical', 'aqua care'],
#   'drug_classes': ['Topical emollients'],
#   'uses': ['Dermatologic disorders',
#    'Keratosis',
#    'Eczema',
#    'Psoriasis',
#    'Dry skin'],
#   'status': 'Rx and/or OTC',
#   'generic_name': 'urea topical',
#   'ingredients': []},
#  {'name': 'Aptensio XR',
#   'alternative_names': ['methylphenidate', 'aptensio xr'],
#   'drug_classes': ['CNS stimulants'],
#   'uses': ['Narcolepsy',
#    'Sleep Disorders',
#    'Attention deficit hyperactivity disorder',
#    'Attention Deficit Disorder'],
#   'status': 'Prescription only',
#   'generic_name': 'methylphenidate',
#   'spl_product_data_elements': ['APTENSIO XR (methylphenidate hydrochloride) METHYLPHENIDATE HYDROCHLORIDE METHYLPHENIDATE SUCROSE STARCH, CORN HYPROMELLOSE, UNSPECIFIED POLYETHYLENE GLYCOL, UNSPECIFIED AMMONIO METHACRYLATE COPOLYMER TYPE B METHACRYLIC ACID AND ETHYL ACRYLATE COPOLYMER TRIETHYL CITRATE TALC WATER SILICON DIOXIDE FD&C BLUE NO. 1 TITANIUM DIOXIDE GELATIN, UNSPECIFIED light turquoise blue cap/white body APTENSIO;XR;10;mg APTENSIO XR (methylphenidate hydrochloride) METHYLPHENIDATE HYDROCHLORIDE METHYLPHENIDATE SUCROSE STARCH, CORN HYPROMELLOSE, UNSPECIFIED POLYETHYLENE GLYCOL, UNSPECIFIED AMMONIO METHACRYLATE COPOLYMER TYPE B METHACRYLIC ACID AND ETHYL ACRYLATE COPOLYMER TRIETHYL CITRATE TALC WATER SILICON DIOXIDE D&C RED NO. 28 D&C YELLOW NO. 10 FD&C RED NO. 40 TITANIUM DIOXIDE GELATIN, UNSPECIFIED orange cap/white body APTENSIO;XR;15;mg APTENSIO XR (methylphenidate hydrochloride) METHYLPHENIDATE HYDROCHLORIDE METHYLPHENIDATE SUCROSE STARCH, CORN HYPROMELLOSE, UNSPECIFIED POLYETHYLENE GLYCOL, UNSPECIFIED AMMONIO METHACRYLATE COPOLYMER TYPE B METHACRYLIC ACID AND ETHYL ACRYLATE COPOLYMER TRIETHYL CITRATE TALC WATER SILICON DIOXIDE D&C RED NO. 33 D&C YELLOW NO. 10 TITANIUM DIOXIDE GELATIN, UNSPECIFIED yellow cap/white body APTENSIO;XR;20;mg APTENSIO XR (methylphenidate hydrochloride) METHYLPHENIDATE HYDROCHLORIDE METHYLPHENIDATE SUCROSE STARCH, CORN HYPROMELLOSE, UNSPECIFIED POLYETHYLENE GLYCOL, UNSPECIFIED AMMONIO METHACRYLATE COPOLYMER TYPE B METHACRYLIC ACID AND ETHYL ACRYLATE COPOLYMER TRIETHYL CITRATE TALC WATER SILICON DIOXIDE FD&C BLUE NO. 1 FD&C RED NO. 3 TITANIUM DIOXIDE GELATIN, UNSPECIFIED blue violet cap/white body APTENSIO;XR;30;mg APTENSIO XR (methylphenidate hydrochloride) METHYLPHENIDATE HYDROCHLORIDE METHYLPHENIDATE SUCROSE STARCH, CORN HYPROMELLOSE, UNSPECIFIED POLYETHYLENE GLYCOL, UNSPECIFIED AMMONIO METHACRYLATE COPOLYMER TYPE B METHACRYLIC ACID AND ETHYL ACRYLATE COPOLYMER TRIETHYL CITRATE TALC WATER SILICON DIOXIDE FD&C BLUE NO. 1 D&C RED NO. 28 FD&C RED NO. 40 TITANIUM DIOXIDE GELATIN, UNSPECIFIED pink cap/white body APTENSIO;XR;40;mg APTENSIO XR (methylphenidate hydrochloride) METHYLPHENIDATE HYDROCHLORIDE METHYLPHENIDATE SUCROSE STARCH, CORN HYPROMELLOSE, UNSPECIFIED POLYETHYLENE GLYCOL, UNSPECIFIED AMMONIO METHACRYLATE COPOLYMER TYPE B METHACRYLIC ACID AND ETHYL ACRYLATE COPOLYMER TRIETHYL CITRATE TALC WATER SILICON DIOXIDE D&C YELLOW NO. 10 FD&C GREEN NO. 3 TITANIUM DIOXIDE GELATIN, UNSPECIFIED green cap/white body APTENSIO;XR;50;mg APTENSIO XR (methylphenidate hydrochloride) METHYLPHENIDATE HYDROCHLORIDE METHYLPHENIDATE SUCROSE STARCH, CORN HYPROMELLOSE, UNSPECIFIED POLYETHYLENE GLYCOL, UNSPECIFIED AMMONIO METHACRYLATE COPOLYMER TYPE B METHACRYLIC ACID AND ETHYL ACRYLATE COPOLYMER TRIETHYL CITRATE TALC WATER SILICON DIOXIDE FERROSOFERRIC OXIDE TITANIUM DIOXIDE GELATIN, UNSPECIFIED gray cap/white body APTENSIO;XR;60;mg'],
#   'ingredients': ['methylphenidate hydrochloride',
#    'Glycol',
#    'hypromellose',
#    'quinoline yellow',
#    'Aptensio XR',
#    'gelatin',
#    'polyethylenes',
#    'water',
#    'nitric oxide',
#    'Citrates',
#    'erythrosine']},
#  {'name': 'Aprodine',
#   'alternative_names': ['pseudoephedrine-triprolidine',
#    'pseudoephedrine and triprolidine',
#    'aprodine'],
#   'drug_classes': ['Upper respiratory combinations'],
#   'uses': ['Rhinorrhea',
#    'Excessive tearing',
#    'Sneezing',
#    'Congestion',
#    'Nasal congestion (finding)',
#    'Pruritus',
#    'Hypersensitivity'],
#   'status': 'Rx and/or OTC',
#   'generic_name': 'pseudoephedrine-triprolidine',
#   'spl_product_data_elements': ['Aprodine Pseudoephedrine HCl and Triprolidine HCl PSEUDOEPHEDRINE HYDROCHLORIDE PSEUDOEPHEDRINE TRIPROLIDINE HYDROCHLORIDE TRIPROLIDINE SILICON DIOXIDE STARCH, CORN HYPROMELLOSE, UNSPECIFIED ANHYDROUS LACTOSE MAGNESIUM STEARATE MICROCRYSTALLINE CELLULOSE POLYETHYLENE GLYCOL, UNSPECIFIED STEARIC ACID TITANIUM DIOXIDE 44;178'],
#   'ingredients': ['Aprodine',
#    'triprolidine',
#    'starch',
#    'Glycol',
#    'pseudoephedrine',
#    'triprolidine hydrochloride',
#    'hypromellose',
#    'dioxide',
#    'stearic acid',
#    'polyethylenes',
#    'Stearates',
#    'pseudoephedrine hydrochloride']},
#  {'name': 'Apri',
#   'alternative_names': ['desogestrel-ethinyl-estradiol',
#    'ethinyl estradiol and desogestrel',
#    'apri'],
#   'drug_classes': ['Contraceptives'],
#   'uses': ['Contraceptive methods'],
#   'status': 'Prescription only',
#   'generic_name': 'desogestrel-ethinyl-estradiol',
#   'spl_product_data_elements': ['Apri 28 Day Desogestrel and Ethinyl Estradiol Desogestrel and Ethinyl Estradiol Desogestrel and Ethinyl Estradiol DESOGESTREL DESOGESTREL ETHINYL ESTRADIOL ETHINYL ESTRADIOL SILICON DIOXIDE FD&C BLUE NO. 2 INDIGOTINDISULFONATE SODIUM FD&C RED NO. 40 HYPROMELLOSE 2910 (3 MPA.S) HYPROMELLOSE 2910 (6 MPA.S) LACTOSE MONOHYDRATE POLYETHYLENE GLYCOL 400 POLYETHYLENE GLYCOL 8000 POLYSORBATE 80 POVIDONE K30 STARCH, CORN STEARIC ACID TITANIUM DIOXIDE ALPHA-TOCOPHEROL rose-colored dp;575 Inert Inert ANHYDROUS LACTOSE MAGNESIUM STEARATE MICROCRYSTALLINE CELLULOSE STARCH, CORN dp;570'],
#   'ingredients': ['starch',
#    'desogestrel / ethinyl estradiol',
#    'mestranol',
#    'indigo carmine',
#    'alpha tocopherol',
#    'desogestrel',
#    'polyethylenes',
#    'Apri',
#    'nitric oxide',
#    'Stearates',
#    'erythrosine',
#    'polysorbates']},
#  {'name': 'Apretude',
#   'alternative_names': ['apretude', 'cabotegravir'],
#   'drug_classes': ['Integrase strand transfer inhibitor'],
#   'uses': ['Primary immune deficiency disorder',
#    'Acquired Immunodeficiency Syndrome'],
#   'status': 'Prescription only',
#   'generic_name': 'cabotegravir',
#   'spl_product_data_elements': ['Apretude Cabotegravir Cabotegravir Cabotegravir CABOTEGRAVIR CABOTEGRAVIR MANNITOL POLYETHYLENE GLYCOL 3350 POLYSORBATE 20 WATER white to light pink'],
#   'ingredients': ['water', 'polyethylene glycols', 'polysorbates']},
#  {'name': 'Apresoline',
#   'alternative_names': ['hydralazine', 'apresoline'],
#   'drug_classes': ['Vasodilators'],
#   'uses': ['Hypertensive disease'],
#   'status': 'Prescription only',
#   'generic_name': 'hydralazine',
#   'spl_product_data_elements': ['Hydralazine Hydrochloride Hydralazine Hydrochloride ANHYDROUS LACTOSE CELLULOSE, MICROCRYSTALLINE STARCH, CORN MAGNESIUM STEARATE LIGHT MINERAL OIL TITANIUM DIOXIDE SODIUM LAURYL SULFATE FD&C RED NO. 40 HYPROMELLOSE, UNSPECIFIED HYDRALAZINE HYDROCHLORIDE HYDRALAZINE HP;1 Hydralazine Hydrochloride Hydralazine Hydrochloride ANHYDROUS LACTOSE CELLULOSE, MICROCRYSTALLINE STARCH, CORN MAGNESIUM STEARATE LIGHT MINERAL OIL TITANIUM DIOXIDE SODIUM LAURYL SULFATE FD&C RED NO. 40 HYPROMELLOSE, UNSPECIFIED HYDRALAZINE HYDROCHLORIDE HYDRALAZINE HP;2 Hydralazine Hydrochloride Hydralazine Hydrochloride ANHYDROUS LACTOSE CELLULOSE, MICROCRYSTALLINE STARCH, CORN MAGNESIUM STEARATE LIGHT MINERAL OIL TITANIUM DIOXIDE SODIUM LAURYL SULFATE FD&C RED NO. 40 HYPROMELLOSE, UNSPECIFIED HYDRALAZINE HYDROCHLORIDE HYDRALAZINE HP;3 Hydralazine Hydrochloride Hydralazine Hydrochloride ANHYDROUS LACTOSE CELLULOSE, MICROCRYSTALLINE STARCH, CORN MAGNESIUM STEARATE LIGHT MINERAL OIL TITANIUM DIOXIDE SODIUM LAURYL SULFATE FD&C RED NO. 40 HYPROMELLOSE, UNSPECIFIED HYDRALAZINE HYDROCHLORIDE HYDRALAZINE HP;4'],
#   'ingredients': ['anhydrous lactose',
#    'starch',
#    'hydralazine hydrochloride',
#    'microcrystalline',
#    'hypromellose',
#    'nitric oxide']},
#  {'name': 'Aprepitant',
#   'alternative_names': ['aprepitant', 'aponvie'],
#   'drug_classes': ['NK1 receptor antagonists'],
#   'uses': ['Nausea', 'Pharmacotherapy', 'Liquid diet', 'Vomiting'],
#   'status': 'Prescription only',
#   'generic_name': 'aprepitant',
#   'spl_product_data_elements': ['APREPITANT APREPITANT POLOXAMER 407 SUCROSE MICROCRYSTALLINE CELLULOSE GELATIN TITANIUM DIOXIDE SODIUM LAURYL SULFATE FERRIC OXIDE YELLOW HYPROMELLOSE 2910 (5 MPA.S) SHELLAC FERROSOFERRIC OXIDE PROPYLENE GLYCOL APREPITANT APREPITANT White body and yellow cap hard gelatin capsules 40mg APREPITANT APREPITANT POLOXAMER 407 SUCROSE MICROCRYSTALLINE CELLULOSE GELATIN TITANIUM DIOXIDE SODIUM LAURYL SULFATE HYPROMELLOSE 2910 (5 MPA.S) SHELLAC FERROSOFERRIC OXIDE PROPYLENE GLYCOL APREPITANT APREPITANT White body and white cap hard gelatin capsules 80mg APREPITANT APREPITANT APREPITANT APREPITANT POLOXAMER 407 SUCROSE MICROCRYSTALLINE CELLULOSE GELATIN TITANIUM DIOXIDE SODIUM LAURYL SULFATE HYPROMELLOSE 2910 (5 MPA.S) SHELLAC FERROSOFERRIC OXIDE PROPYLENE GLYCOL APREPITANT APREPITANT white body and white cap hard gelatin capsule 80mg APREPITANT APREPITANT POLOXAMER 407 SUCROSE MICROCRYSTALLINE CELLULOSE GELATIN TITANIUM DIOXIDE SODIUM LAURYL SULFATE FERRIC OXIDE RED HYPROMELLOSE 2910 (5 MPA.S) SHELLAC FERROSOFERRIC OXIDE PROPYLENE GLYCOL APREPITANT APREPITANT white body and pink cap hard gelatin capsule 125mg APREPITANT APREPITANT POLOXAMER 407 SUCROSE MICROCRYSTALLINE CELLULOSE GELATIN TITANIUM DIOXIDE SODIUM LAURYL SULFATE FERRIC OXIDE RED HYPROMELLOSE 2910 (5 MPA.S) SHELLAC FERROSOFERRIC OXIDE PROPYLENE GLYCOL APREPITANT APREPITANT White body and pink cap hard gelatin capsules 125mg'],
#   'ingredients': ['shellac',
#    'aprepitant',
#    'ferrosoferric oxide',
#    'poloxamer']},
#  {'name': 'Apremilast',
#   'alternative_names': ['otezla', 'apremilast'],
#   'drug_classes': ['Antirheumatics'],
#   'uses': ['Behcet Syndrome',
#    'Phototherapy',
#    'Dental Plaque',
#    'Therapeutic procedure',
#    'Inflammation',
#    'Ulcer',
#    'Psoriasis',
#    'Arthritis, Psoriatic',
#    'Disease'],
#   'status': 'Prescription only',
#   'generic_name': 'apremilast',
#   'spl_product_data_elements': ['APREMILAST APREMILAST CROSCARMELLOSE SODIUM LACTOSE MONOHYDRATE MAGNESIUM STEARATE CELLULOSE, MICROCRYSTALLINE TITANIUM DIOXIDE POLYETHYLENE GLYCOL 4000 POLYVINYL ALCOHOL TALC APREMILAST APREMILAST white to off-white V;35 Apremilast Apremilast Apremilast Apremilast CROSCARMELLOSE SODIUM LACTOSE MONOHYDRATE MAGNESIUM STEARATE CELLULOSE, MICROCRYSTALLINE TALC TITANIUM DIOXIDE POLYETHYLENE GLYCOL 4000 POLYVINYL ALCOHOL APREMILAST APREMILAST white to off-white V;33 Apremilast Apremilast CROSCARMELLOSE SODIUM LACTOSE MONOHYDRATE MAGNESIUM STEARATE CELLULOSE, MICROCRYSTALLINE POLYVINYL ALCOHOL TALC TITANIUM DIOXIDE POLYETHYLENE GLYCOL 4000 APREMILAST APREMILAST white to off-white V;34 Apremilast Apremilast CROSCARMELLOSE SODIUM LACTOSE MONOHYDRATE MAGNESIUM STEARATE CELLULOSE, MICROCRYSTALLINE POLYVINYL ALCOHOL TALC TITANIUM DIOXIDE POLYETHYLENE GLYCOL 4000 APREMILAST APREMILAST white to off-white V;35 Apremilast Apremilast Apremilast Apremilast CROSCARMELLOSE SODIUM LACTOSE MONOHYDRATE MAGNESIUM STEARATE CELLULOSE, MICROCRYSTALLINE POLYVINYL ALCOHOL TALC TITANIUM DIOXIDE POLYETHYLENE GLYCOL 4000 APREMILAST APREMILAST white to off-white V;35 Apremilast Apremilast CROSCARMELLOSE SODIUM LACTOSE MONOHYDRATE MAGNESIUM STEARATE CELLULOSE, MICROCRYSTALLINE POLYVINYL ALCOHOL TALC TITANIUM DIOXIDE POLYETHYLENE GLYCOL 4000 APREMILAST APREMILAST white to off-white V;33 Apremilast Apremilast CROSCARMELLOSE SODIUM LACTOSE MONOHYDRATE MAGNESIUM STEARATE CELLULOSE, MICROCRYSTALLINE POLYVINYL ALCOHOL TALC TITANIUM DIOXIDE POLYETHYLENE GLYCOL 4000 APREMILAST APREMILAST white to off-white V;34'],
#   'ingredients': ['microcrystalline',
#    'apremilast',
#    'talc',
#    'cellulose',
#    'Stearates',
#    'Polyvinyls']},
#  {'name': 'Apraclonidine ophthalmic',
#   'alternative_names': ['apraclonidine-ophthalmic',
#    'iopidine',
#    'apraclonidine ophthalmic'],
#   'drug_classes': ['Ophthalmic glaucoma agents'],
#   'uses': [],
#   'status': 'Prescription only',
#   'generic_name': 'apraclonidine-ophthalmic',
#   'spl_product_data_elements': ['Apraclonidine Ophthalmic Apraclonidine Hydrochloride apraclonidine hydrochloride apraclonidine benzalkonium chloride sodium acetate sodium chloride hydrochloric acid water'],
#   'ingredients': ['apraclonidine hydrochloride', 'apraclonidine']},
#  {'name': 'Appearex',
#   'alternative_names': ['biotin', 'appearex'],
#   'drug_classes': ['Vitamins'],
#   'uses': ['Herbal Supplements',
#    'Prophylactic treatment',
#    'Seborrheic dermatitis',
#    'Digital Arthropathy-Brachydactyly, Familial',
#    'Diabetes',
#    'Multiple Sclerosis',
#    'Malnutrition',
#    'Nerve Pain',
#    'Alopecia',
#    'Enteral Nutrition',
#    'Mental Depression'],
#   'status': 'Rx and/or OTC',
#   'generic_name': 'biotin',
#   'spl_product_data_elements': ["Pediatric Infuvite Multiple Vitamins Ascorbic Acid, Vitamin A Palmitate, Cholecalciferol, Thiamine Hydrochloride, Riboflavin-5 phosphate sodium, Pyridoxine Hydrochloride, Niacinamide, Dexpanthenol, Alpha-tocopherol acetate, Vitamin K1, Folic Acid, Biotin, Cyanocobalamin Pediatric Infuvite Multiple Vitamins Ascorbic Acid, Vitamin A Palmitate, Cholecalciferol, Thiamine Hydrochloride, Riboflavin 5-phosphate sodium, Pyridoxine Hydrochloride, Niacinamide, Dexpanthenol, Alpha-tocopherol acetate, Vitamin K1 ASCORBIC ACID ASCORBIC ACID VITAMIN A PALMITATE VITAMIN A CHOLECALCIFEROL CHOLECALCIFEROL THIAMINE HYDROCHLORIDE THIAMINE ION THIAMINE RIBOFLAVIN 5'-PHOSPHATE SODIUM FLAVIN MONONUCLEOTIDE PYRIDOXINE HYDROCHLORIDE PYRIDOXINE NIACINAMIDE NIACINAMIDE DEXPANTHENOL DEXPANTHENOL .ALPHA.-TOCOPHEROL ACETATE .ALPHA.-TOCOPHEROL PHYTONADIONE PHYTONADIONE POLYSORBATE 80 SODIUM HYDROXIDE HYDROCHLORIC ACID WATER Pediatric Infuvite Multiple Vitamins Folic Acid, Biotin, Cyanocobalamin FOLIC ACID FOLIC ACID BIOTIN BIOTIN CYANOCOBALAMIN CYANOCOBALAMIN MANNITOL ANHYDROUS CITRIC ACID SODIUM CITRATE, UNSPECIFIED FORM WATER Pediatric Infuvite Multiple Vitamins Ascorbic Acid, Vitamin A Palmitate, Cholecalciferol, Thiamine Hydrochloride, Riboflavin-5 phosphate sodium, Pyridoxine Hydrochloride, Niacinamide, Dexpanthenol, Alpha-tocopherol acetate, Vitamin K1, Folic Acid, Biotin, Cyanocobalamin ASCORBIC ACID ASCORBIC ACID VITAMIN A PALMITATE VITAMIN A CHOLECALCIFEROL CHOLECALCIFEROL THIAMINE HYDROCHLORIDE THIAMINE ION THIAMINE RIBOFLAVIN 5'-PHOSPHATE SODIUM FLAVIN MONONUCLEOTIDE PYRIDOXINE HYDROCHLORIDE PYRIDOXINE NIACINAMIDE NIACINAMIDE DEXPANTHENOL DEXPANTHENOL .ALPHA.-TOCOPHEROL ACETATE .ALPHA.-TOCOPHEROL PHYTONADIONE PHYTONADIONE FOLIC ACID FOLIC ACID BIOTIN BIOTIN CYANOCOBALAMIN CYANOCOBALAMIN POLYSORBATE 80 ANHYDROUS CITRIC ACID SODIUM CITRATE, UNSPECIFIED FORM SODIUM HYDROXIDE HYDROCHLORIC ACID WATER MANNITOL"],
#   'ingredients': ['Pediatric brand name',
#    'water',
#    'Infuvite Pediatric',
#    'polysorbates',
#    'alpha-tocopherol acetate',
#    'Multivitamin preparation',
#    'cholecalciferol',
#    'biotin',
#    "riboflavin 5'-phosphate sodium",
#    'niacinamide',
#    'palmitate',
#    'vitamin B12',
#    'thiamine hydrochloride',
#    'vitamin A',
#    'sodium',
#    'Citrates',
#    'dexpanthenol',
#    'vitamin K1',
#    'vitamin A palmitate',
#    'folic acid',
#    'citric acid',
#    'pyridoxine hydrochloride',
#    'ascorbic acid',
#    'anhydrous dextrose']},
#  {'name': 'Apomorphine',
#   'alternative_names': ['apomorphine', 'apokyn'],
#   'drug_classes': ['Dopaminergic antiparkinsonism agents'],
#   'uses': ['Injection of therapeutic agent',
#    'nervous system disorder',
#    'Digital Arthropathy-Brachydactyly, Familial',
#    'Parkinson Disease'],
#   'status': 'Prescription only',
#   'generic_name': 'apomorphine',
#   'spl_product_data_elements': ['apomorphine hydrocloride APOMORPHINE HYDROCHLORIDE APOMORPHINE HYDROCHLORIDE APOMORPHINE sodium metabisulfite benzyl alcohol water sodium hydroxide hydrochloric acid'],
#   'ingredients': ['penicillin G', 'apomorphine hydrochloride']},
#  {'name': 'Aplenzin',
#   'alternative_names': ['bupropion',
#    'aplenzin',
#    'bupropion hydrobromide extended-release tablets'],
#   'drug_classes': ['Miscellaneous antidepressants'],
#   'uses': ['Depressive disorder', 'Seasonal Affective Disorder'],
#   'status': 'Prescription only',
#   'generic_name': 'bupropion',
#   'spl_product_data_elements': ['Aplenzin bupropion hydrobromide BUPROPION HYDROBROMIDE BUPROPION GLYCERYL DIBEHENATE DIBUTYL SEBACATE CARNAUBA WAX ETHYLCELLULOSE, UNSPECIFIED POLYVINYL ALCOHOL, UNSPECIFIED POLYETHYLENE GLYCOL, UNSPECIFIED CROSPOVIDONE white to off-white BR;174 Aplenzin bupropion hydrobromide BUPROPION HYDROBROMIDE BUPROPION GLYCERYL DIBEHENATE DIBUTYL SEBACATE CARNAUBA WAX ETHYLCELLULOSE, UNSPECIFIED POLYVINYL ALCOHOL, UNSPECIFIED POLYETHYLENE GLYCOL, UNSPECIFIED CROSPOVIDONE white to off-white BR;348 Aplenzin bupropion hydrobromide BUPROPION HYDROBROMIDE BUPROPION GLYCERYL DIBEHENATE DIBUTYL SEBACATE ETHYLCELLULOSE, UNSPECIFIED POLYVINYL ALCOHOL, UNSPECIFIED POLYETHYLENE GLYCOL, UNSPECIFIED CROSPOVIDONE white to off-white BR;522'],
#   'ingredients': ['Glycol',
#    'sebacate',
#    'ethanol',
#    'polyethylenes',
#    'methylcellulose',
#    'bupropion hydrobromide',
#    'Polyvinyls']},
#  {'name': 'Apidra',
#   'alternative_names': ['insulin glulisine', 'insulin-glulisine', 'apidra'],
#   'drug_classes': ['Insulin'],
#   'uses': ['Injection of therapeutic agent',
#    'Diabetes Mellitus',
#    'Diabetes Mellitus, Insulin-Dependent',
#    'Diabetes Mellitus, Non-Insulin-Dependent'],
#   'status': 'Prescription only',
#   'generic_name': 'insulin-glulisine',
#   'spl_product_data_elements': ['Apidra insulin glulisine INSULIN GLULISINE INSULIN GLULISINE METACRESOL TROMETHAMINE SODIUM CHLORIDE POLYSORBATE 20 WATER HYDROCHLORIC ACID SODIUM HYDROXIDE Apidra SoloStar insulin glulisine INSULIN GLULISINE INSULIN GLULISINE METACRESOL TROMETHAMINE SODIUM CHLORIDE POLYSORBATE 20 WATER HYDROCHLORIC ACID SODIUM HYDROXIDE'],
#   'ingredients': ['water', 'Apidra', 'insulin glulisine, human']},
#  {'name': 'Aphthasol',
#   'alternative_names': ['amlexanox', 'aphthasol'],
#   'drug_classes': ['Mouth and throat products'],
#   'uses': ['Aphthous Stomatitis', 'Oral Ulcer'],
#   'status': 'Discontinued',
#   'generic_name': 'amlexanox',
#   'ingredients': []},
#  {'name': 'Aphexda',
#   'alternative_names': ['motixafortide', 'aphexda'],
#   'drug_classes': ['Hematopoietic stem cell mobilizer'],
#   'uses': ['Mental blocking',
#    'Digital Arthropathy-Brachydactyly, Familial',
#    'Stem cell transplant',
#    'Therapeutic Mobilization',
#    'Transplantation, Autologous',
#    'Placebos'],
#   'status': 'Prescription only',
#   'generic_name': 'motixafortide',
#   'spl_product_data_elements': ['Aphexda Motixafortide MANNITOL MOTIXAFORTIDE ACETATE MOTIXAFORTIDE HYDROCHLORIC ACID'],
#   'ingredients': ['Motixafortide']},
#  {'name': 'Aphedrid',
#   'alternative_names': ['pseudoephedrine-triprolidine',
#    'pseudoephedrine and triprolidine',
#    'aphedrid'],
#   'drug_classes': ['Upper respiratory combinations'],
#   'uses': ['Rhinorrhea',
#    'Excessive tearing',
#    'Sneezing',
#    'Congestion',
#    'Nasal congestion (finding)',
#    'Pruritus',
#    'Hypersensitivity'],
#   'status': 'Rx and/or OTC',
#   'generic_name': 'pseudoephedrine-triprolidine',
#   'spl_product_data_elements': ['Pseudoephedrine hydrochloride PSEUDOEPHEDRINE HYDROCHLORIDE PSEUDOEPHEDRINE HYDROCHLORIDE PSEUDOEPHEDRINE CASTOR OIL SILICON DIOXIDE HYPROMELLOSE, UNSPECIFIED MICROCRYSTALLINE CELLULOSE MAGNESIUM STEARATE TITANIUM DIOXIDE 204'],
#   'ingredients': ['magnesium',
#    'titanium dioxide',
#    'pseudoephedrine',
#    'microcrystalline',
#    'castor oil',
#    'Stearates',
#    'pseudoephedrine hydrochloride']},
#  {'name': 'ApexiCon E',
#   'alternative_names': ['apexicon e',
#    'diflorasone-topical',
#    'diflorasone topical'],
#   'drug_classes': ['Topical steroids'],
#   'uses': ['Dermatologic disorders', 'Eczema', 'Psoriasis', 'Inflammation'],
#   'status': 'Prescription only',
#   'generic_name': 'diflorasone-topical',
#   'spl_product_data_elements': ['ApexiCon E diflorasone diacetate diflorasone diacetate diflorasone Stearyl Alcohol Cetyl Alcohol Sorbitan Monostearate Mineral Oil Water Polysorbate 60 Propylene Glycol white to off-white'],
#   'ingredients': ['diflorasone diacetate',
#    'propylene glycol',
#    'cetyl alcohol']},
#  {'name': 'ApexiCon',
#   'alternative_names': ['apexicon',
#    'diflorasone-topical',
#    'diflorasone topical'],
#   'drug_classes': ['Topical steroids'],
#   'uses': ['Dermatologic disorders', 'Eczema', 'Psoriasis', 'Inflammation'],
#   'status': 'Prescription only',
#   'generic_name': 'diflorasone-topical',
#   'spl_product_data_elements': ['ApexiCon E diflorasone diacetate diflorasone diacetate diflorasone Stearyl Alcohol Cetyl Alcohol Sorbitan Monostearate Mineral Oil Water Polysorbate 60 Propylene Glycol white to off-white'],
#   'ingredients': ['diflorasone diacetate',
#    'propylene glycol',
#    'cetyl alcohol']},
#  {'name': 'Apadaz',
#   'alternative_names': ['apadaz',
#    'acetaminophen-benzhydrocodone',
#    'acetaminophen and benzhydrocodone'],
#   'drug_classes': ['Narcotic analgesic combinations'],
#   'uses': ['Pain'],
#   'status': 'Prescription only',
#   'generic_name': 'acetaminophen-benzhydrocodone',
#   'spl_product_data_elements': ['APADAZ Benzhydrocodone and Acetaminophen CELLULOSE, MICROCRYSTALLINE STARCH, CORN CROSPOVIDONE POVIDONE K30 STEARIC ACID BENZHYDROCODONE HYDROCHLORIDE BENZHYDROCODONE ACETAMINOPHEN ACETAMINOPHEN KP201;890 APADAZ Benzhydrocodone and Acetaminophen CELLULOSE, MICROCRYSTALLINE STARCH, CORN CROSPOVIDONE POVIDONE K30 STEARIC ACID BENZHYDROCODONE HYDROCHLORIDE BENZHYDROCODONE ACETAMINOPHEN ACETAMINOPHEN KP201 APADAZ Benzhydrocodone and Acetaminophen CELLULOSE, MICROCRYSTALLINE STARCH, CORN CROSPOVIDONE POVIDONE K30 STEARIC ACID BENZHYDROCODONE HYDROCHLORIDE BENZHYDROCODONE ACETAMINOPHEN ACETAMINOPHEN KP201;445'],
#   'ingredients': ['starch',
#    'Apadaz',
#    'microcrystalline',
#    'acetaminophen',
#    'benzhydrocodone',
#    'povidone']},
#  {'name': 'A-Phedrin',
#   'alternative_names': ['pseudoephedrine-triprolidine',
#    'pseudoephedrine and triprolidine',
#    'a-phedrin'],
#   'drug_classes': ['Upper respiratory combinations'],
#   'uses': ['Rhinorrhea',
#    'Excessive tearing',
#    'Sneezing',
#    'Congestion',
#    'Nasal congestion (finding)',
#    'Pruritus',
#    'Hypersensitivity'],
#   'status': 'Rx and/or OTC',
#   'generic_name': 'pseudoephedrine-triprolidine',
#   'spl_product_data_elements': ['Pseudoephedrine hydrochloride PSEUDOEPHEDRINE HYDROCHLORIDE PSEUDOEPHEDRINE HYDROCHLORIDE PSEUDOEPHEDRINE CASTOR OIL SILICON DIOXIDE HYPROMELLOSE, UNSPECIFIED MICROCRYSTALLINE CELLULOSE MAGNESIUM STEARATE TITANIUM DIOXIDE 204'],
#   'ingredients': ['magnesium',
#    'titanium dioxide',
#    'pseudoephedrine',
#    'microcrystalline',
#    'castor oil',
#    'Stearates',
#    'pseudoephedrine hydrochloride']},
#  {'name': 'Anusol-HC',
#   'alternative_names': ['hydrocortisone topical',
#    'hydrocortisone-topical',
#    'anusol-hc'],
#   'drug_classes': ['Topical steroids'],
#   'uses': ['Pruritus', 'Dermatologic disorders', 'Inflammation'],
#   'status': 'Prescription only',
#   'generic_name': 'hydrocortisone-topical',
#   'spl_product_data_elements': ['Anusol HC hydrocortisone HYDROCORTISONE HYDROCORTISONE BENZYL ALCOHOL PETROLATUM STEARYL ALCOHOL PROPYLENE GLYCOL ISOPROPYL MYRISTATE POLYOXYL 40 STEARATE CARBOMER HOMOPOLYMER TYPE B (ALLYL SUCROSE CROSSLINKED) SODIUM LAURYL SULFATE EDETATE DISODIUM SODIUM HYDROXIDE WATER'],
#   'ingredients': ['carbomer',
#    'isopropyl alcohol',
#    'hydrocortisone',
#    'water',
#    'Stearates']},
#  {'name': 'Anucort-HC',
#   'alternative_names': ['anucort-hc (cream, suppository)',
#    'hydrocortisone rectal (cream, suppository)',
#    'hydrocortisone-topical'],
#   'drug_classes': ['Topical steroids'],
#   'uses': ['Pruritus', 'Edema', 'Hemorrhoids', 'Ulcerative Colitis'],
#   'status': 'Prescription only',
#   'generic_name': 'hydrocortisone-topical',
#   'spl_product_data_elements': ['ANUCORT-HC Hydrocortisone Acetate HYDROGENATED PALM KERNEL OIL HYDROCORTISONE ACETATE HYDROCORTISONE'],
#   'ingredients': ['Anucort-HC', 'hydrocortisone acetate']},
#  {'name': 'Anu-Med',
#   'alternative_names': ['phenylephrine',
#    'phenylephrine-topical',
#    'anu-med (rectal)'],
#   'drug_classes': ['Anorectal preparations'],
#   'uses': ['Pruritus', 'Edema', 'Hemorrhoids', 'Burning sensation'],
#   'status': 'Rx and/or OTC',
#   'generic_name': 'phenylephrine-topical',
#   'spl_product_data_elements': ['Tussin CF Non Drowsy Multi Symptom Dextromethorphan HBr, Guaifenesin, Phenylephrine HCl DEXTROMETHORPHAN HYDROBROMIDE DEXTROMETHORPHAN GUAIFENESIN GUAIFENESIN PHENYLEPHRINE HYDROCHLORIDE PHENYLEPHRINE ANHYDROUS CITRIC ACID GLYCERIN PROPYLENE GLYCOL WATER SODIUM BENZOATE FD&C RED NO. 40 LACTIC ACID MENTHOL SORBITOL SUCRALOSE'],
#   'ingredients': ['phenylephrine hydrochloride',
#    'dextromethorphan',
#    'Tussin CF',
#    'guaifenesin',
#    'citric acid',
#    'nitric oxide',
#    'erythrosine',
#    'scopolamine hydrobromide',
#    'guaifenesin / phenylephrine',
#    'Benzoates']},
#  {'name': 'Anturol',
#   'alternative_names': ['anturol', 'oxybutynin'],
#   'drug_classes': ['Urinary antispasmodics'],
#   'uses': ['Extravasation of urine', 'Incontinence', 'Spasm'],
#   'status': 'Discontinued',
#   'generic_name': 'oxybutynin',
#   'spl_product_data_elements': ['Oxybutynin Chloride Extended Release Oxybutynin Chloride ANHYDROUS LACTOSE LACTOSE MONOHYDRATE MANNITOL ANHYDROUS DEXTROSE TARTARIC ACID SILICON DIOXIDE MAGNESIUM STEARATE CELLULOSE ACETATE POLYETHYLENE GLYCOL 400 TITANIUM DIOXIDE FERROSOFERRIC OXIDE PROPYLENE GLYCOL HYPROMELLOSE 2208 (100 MPA.S) TRIACETIN OXYBUTYNIN CHLORIDE OXYBUTYNIN KU;270 Oxybutynin Chloride Extended Release Oxybutynin Chloride ANHYDROUS LACTOSE LACTOSE MONOHYDRATE MANNITOL ANHYDROUS DEXTROSE TARTARIC ACID SILICON DIOXIDE MAGNESIUM STEARATE CELLULOSE ACETATE POLYETHYLENE GLYCOL 400 TITANIUM DIOXIDE FERROSOFERRIC OXIDE PROPYLENE GLYCOL HYPROMELLOSE 2208 (100 MPA.S) TRIACETIN OXYBUTYNIN CHLORIDE OXYBUTYNIN KU;271 Oxybutynin Chloride Extended Release Oxybutynin Chloride SILICON DIOXIDE MAGNESIUM STEARATE CELLULOSE ACETATE POLYETHYLENE GLYCOL 400 TITANIUM DIOXIDE FERROSOFERRIC OXIDE PROPYLENE GLYCOL HYPROMELLOSE 2208 (100 MPA.S) TRIACETIN OXYBUTYNIN CHLORIDE OXYBUTYNIN ANHYDROUS LACTOSE LACTOSE MONOHYDRATE MANNITOL ANHYDROUS DEXTROSE TARTARIC ACID KU;272'],
#   'ingredients': ['polyethylenes',
#    'oxybutynin chloride',
#    'Stearates',
#    'lactose']},
#  {'name': 'Antizol',
#   'alternative_names': ['antizol', 'fomepizole'],
#   'drug_classes': ['Antidotes'],
#   'uses': ['Hemodialysis', 'Poisoning'],
#   'status': 'Prescription only',
#   'generic_name': 'fomepizole',
#   'spl_product_data_elements': ['Fomepizole Fomepizole Fomepizole Fomepizole'],
#   'ingredients': ['fomepizole']},
#  {'name': 'Antivert',
#   'alternative_names': ['meclizine', 'antivert'],
#   'drug_classes': ['Anticholinergic antiemetics'],
#   'uses': ['Motion Sickness',
#    'Disease',
#    'Dizziness',
#    'Vomiting',
#    'Nausea',
#    'Vertigo'],
#   'status': 'Rx and/or OTC',
#   'generic_name': 'meclizine',
#   'spl_product_data_elements': ['Antivert meclizine HCl MECLIZINE HYDROCHLORIDE MECLIZINE STARCH, CORN SUCROSE WATER POLYETHYLENE GLYCOL, UNSPECIFIED MAGNESIUM STEARATE FD&C BLUE NO. 1 ALCOHOL ANHYDROUS DIBASIC CALCIUM PHOSPHATE Pale Blue to White Biconvex, two layered tablet 34;L Antivert meclizine HCl MECLIZINE HYDROCHLORIDE MECLIZINE ANHYDROUS DIBASIC CALCIUM PHOSPHATE STARCH, CORN SUCROSE WATER POLYETHYLENE GLYCOL, UNSPECIFIED MAGNESIUM STEARATE FD&C YELLOW NO. 6 D&C YELLOW NO. 10 Pale Yellow to White Biconvex, two layered tablet 49;L Antivert meclizine hcl MECLIZINE HYDROCHLORIDE MECLIZINE ANHYDROUS DIBASIC CALCIUM PHOSPHATE FD&C YELLOW NO. 6 D&C YELLOW NO. 10 STARCH, CORN SUCROSE WATER POLYETHYLENE GLYCOL, UNSPECIFIED MAGNESIUM STEARATE FD&C BLUE NO. 1 ALCOHOL Pale Blue to Yellow Biconvex, two layered tablet 50;L Antivert meclizine hcl MECLIZINE HYDROCHLORIDE MECLIZINE STARCH, CORN SILICON DIOXIDE FD&C RED NO. 40 LACTOSE MONOHYDRATE MAGNESIUM STEARATE RASPBERRY SACCHARIN SODIUM TALC Round tablets M;25'],
#   'ingredients': ['starch',
#    'Glycol',
#    'quinoline yellow',
#    'ethanol',
#    'saccharin sodium',
#    'talc',
#    'nitric oxide',
#    'Stearates',
# ...
#    'formaldehyde',
#    'influenza B virus B/Maryland/15/2016 antigen',
#    'Alba brand of Normal Human Serum']},
#  {'name': 'Arestin',
#   'alternative_names': ['arestin (mucous membrane powder)',
#    'minocycline (mucous membrane powder)',
#    'minocycline-topical'],
#   'drug_classes': ['Mouth and throat products'],
#   'uses': ['Dental Procedures',
#    'Gingival Diseases',
#    'Inflammation',
#    'Communicable Diseases',
#    'Periodontitis'],
#   'status': 'Prescription only',
#   'generic_name': 'minocycline-topical',
#   'spl_product_data_elements': ['Arestin Minocycline Hydrochloride Minocycline Hydrochloride Minocycline'],
#   'ingredients': ['Arestin', 'minocycline hydrochloride', 'minocycline']},
#  {'name': 'Aredia',
#   'alternative_names': ['pamidronate', 'aredia'],
#   'drug_classes': ['Bisphosphonates'],
#   'uses': ['Fracture',
#    'Osteitis Deformans',
#    'Osteopenia',
#    'Apparent life threatening event in infant',
#    'Hypercalcemia'],
#   'status': 'Prescription only',
#   'generic_name': 'pamidronate',
#   'spl_product_data_elements': ['Pamidronate Disodium Pamidronate Disodium MANNITOL WATER PHOSPHORIC ACID PAMIDRONATE DISODIUM PAMIDRONIC ACID Pamidronate Disodium Pamidronate Disodium MANNITOL WATER PHOSPHORIC ACID PAMIDRONATE DISODIUM PAMIDRONIC ACID Pamidronate Disodium Pamidronate Disodium MANNITOL WATER PHOSPHORIC ACID PAMIDRONATE DISODIUM PAMIDRONIC ACID'],
#   'ingredients': ['pamidronic acid',
#    'pamidronate disodium',
#    'phosphoric acid']},
#  {'name': 'Arctic Relief',
#   'alternative_names': ['camphor and menthol topical', 'arctic relief'],
#   'drug_classes': ['Topical rubefacient'],
#   'uses': ['Pruritus', 'Arthralgia'],
#   'status': 'Over the counter',
#   'generic_name': 'camphor and menthol topical',
#   'spl_product_data_elements': ['ARCTIC RELIEF MENTHOL, UNSPECIFIED FORM MENTHOL, UNSPECIFIED FORM MENTHOL, UNSPECIFIED FORM CAMPHOR (SYNTHETIC) CARBOMER HOMOPOLYMER TYPE C (ALLYL PENTAERYTHRITOL CROSSLINKED) FD&C BLUE NO. 1 FD&C YELLOW NO. 5 ILEX PARAGUARIENSIS LEAF ISOPROPYL ALCOHOL'],
#   'ingredients': ['menthol',
#    'ethanol',
#    'nitric oxide',
#    'FD&C yellow no. 6',
#    'erythrosine',
#    'Arctic Relief']},
#  {'name': 'Arcapta Neohaler',
#   'alternative_names': ['arcapta neohaler', 'indacaterol'],
#   'drug_classes': ['Adrenergic bronchodilators'],
#   'uses': ['Chronic Obstructive Airway Disease',
#    'Bronchitis, Chronic',
#    'Pathological accumulation of air in tissues',
#    'Asthma'],
#   'status': 'Discontinued',
#   'generic_name': 'indacaterol',
#   'ingredients': []},
#  {'name': 'Arcalyst',
#   'alternative_names': ['arcalyst', 'rilonacept'],
#   'drug_classes': ['Interleukin inhibitors'],
#   'uses': ['Symptom control (regime/therapy)',
#    'Idiopathic recurrent pericarditis',
#    'Fatigue',
#    'Fever',
#    'Arthralgia',
#    'Kidney Failure',
#    'Hereditary Diseases',
#    'Familial cold urticaria',
#    'Inflammation',
#    'Single organ dysfunction',
#    'Inflammatory disorder',
#    'Muckle-Wells Syndrome',
#    'Retinitis Pigmentosa',
#    'Chest Pain',
#    'Dyspnea',
#    'Discomfort',
#    'Redness of eye',
#    'Exanthema'],
#   'status': 'Prescription only',
#   'generic_name': 'rilonacept',
#   'spl_product_data_elements': ['Arcalyst rilonacept RILONACEPT RILONACEPT HISTIDINE ARGININE POLYETHYLENE GLYCOL 3350 SUCROSE GLYCINE'],
#   'ingredients': ['Arcalyst', 'sucrose', 'histidine', 'rilonacept']},
#  {'name': 'Arazlo',
#   'alternative_names': ['tazarotene-topical', 'tazarotene topical', 'arazlo'],
#   'drug_classes': ['Topical acne agents'],
#   'uses': ['Acne Vulgaris', 'Dental Plaque', 'Psoriasis'],
#   'status': 'Prescription only',
#   'generic_name': 'tazarotene-topical',
#   'spl_product_data_elements': ['Arazlo tazarotene CARBOMER COPOLYMER TYPE B (ALLYL PENTAERYTHRITOL CROSSLINKED) CARBOMER HOMOPOLYMER TYPE A (ALLYL PENTAERYTHRITOL CROSSLINKED) DIETHYL SEBACATE EDETATE DISODIUM LIGHT MINERAL OIL METHYLPARABEN PROPYLPARABEN WATER SODIUM HYDROXIDE SORBITAN MONOOLEATE SORBITOL TAZAROTENE TAZAROTENE'],
#   'ingredients': ['sorbitol monooleate', 'sorbitan', 'tazarotene']},
#  {'name': 'Arava',
#   'alternative_names': ['arava', 'leflunomide'],
#   'drug_classes': ['Antirheumatics', 'Selective immunosuppressants'],
#   'uses': ['Edema', 'Rheumatoid Arthritis', 'Inflammation'],
#   'status': 'Prescription only',
#   'generic_name': 'leflunomide',
#   'spl_product_data_elements': ['Arava leflunomide SILICON DIOXIDE CROSPOVIDONE (120 .MU.M) HYPROMELLOSE, UNSPECIFIED LACTOSE MONOHYDRATE MAGNESIUM STEARATE POLYETHYLENE GLYCOL, UNSPECIFIED POVIDONE, UNSPECIFIED TALC TITANIUM DIOXIDE STARCH, CORN LEFLUNOMIDE LEFLUNOMIDE ZBN Arava leflunomide SILICON DIOXIDE CROSPOVIDONE (120 .MU.M) HYPROMELLOSE, UNSPECIFIED LACTOSE MONOHYDRATE MAGNESIUM STEARATE POLYETHYLENE GLYCOL, UNSPECIFIED POVIDONE, UNSPECIFIED TALC TITANIUM DIOXIDE FERRIC OXIDE YELLOW STARCH, CORN LEFLUNOMIDE LEFLUNOMIDE ZBO Arava leflunomide SILICON DIOXIDE CROSPOVIDONE (120 .MU.M) HYPROMELLOSE, UNSPECIFIED LACTOSE MONOHYDRATE MAGNESIUM STEARATE POLYETHYLENE GLYCOL, UNSPECIFIED POVIDONE, UNSPECIFIED TALC TITANIUM DIOXIDE STARCH, CORN LEFLUNOMIDE LEFLUNOMIDE ZBP'],
#   'ingredients': ['Glycol',
#    'starch',
#    'leflunomide',
#    'crospovidone',
#    'talc',
#    'Stearates',
#    'povidone']},
#  {'name': 'Aranesp',
#   'alternative_names': ['darbepoetin alfa', 'aranesp', 'darbepoetin-alfa'],
#   'drug_classes': ['Recombinant human erythropoietins'],
#   'uses': ['Anemia',
#    'Kidney Failure',
#    'Chronic Kidney Diseases',
#    'Pharmacotherapy'],
#   'status': 'Prescription only',
#   'generic_name': 'darbepoetin-alfa',
#   'spl_product_data_elements': ['ARANESP darbepoetin alfa DARBEPOETIN ALFA DARBEPOETIN ALFA POLYSORBATE 80 SODIUM CHLORIDE WATER SODIUM PHOSPHATE, DIBASIC, ANHYDROUS SODIUM PHOSPHATE, MONOBASIC, MONOHYDRATE ARANESP darbepoetin alfa DARBEPOETIN ALFA DARBEPOETIN ALFA POLYSORBATE 80 SODIUM CHLORIDE WATER SODIUM PHOSPHATE, DIBASIC, ANHYDROUS SODIUM PHOSPHATE, MONOBASIC, MONOHYDRATE ARANESP darbepoetin alfa DARBEPOETIN ALFA DARBEPOETIN ALFA POLYSORBATE 80 SODIUM CHLORIDE WATER SODIUM PHOSPHATE, DIBASIC, ANHYDROUS SODIUM PHOSPHATE, MONOBASIC, MONOHYDRATE ARANESP darbepoetin alfa DARBEPOETIN ALFA DARBEPOETIN ALFA POLYSORBATE 80 SODIUM CHLORIDE WATER SODIUM PHOSPHATE, DIBASIC, ANHYDROUS SODIUM PHOSPHATE, MONOBASIC, MONOHYDRATE ARANESP darbepoetin alfa DARBEPOETIN ALFA DARBEPOETIN ALFA POLYSORBATE 80 SODIUM CHLORIDE WATER SODIUM PHOSPHATE, DIBASIC, ANHYDROUS SODIUM PHOSPHATE, MONOBASIC, MONOHYDRATE ARANESP darbepoetin alfa DARBEPOETIN ALFA DARBEPOETIN ALFA POLYSORBATE 80 SODIUM CHLORIDE WATER SODIUM PHOSPHATE, DIBASIC, ANHYDROUS SODIUM PHOSPHATE, MONOBASIC, MONOHYDRATE ARANESP darbepoetin alfa DARBEPOETIN ALFA DARBEPOETIN ALFA POLYSORBATE 80 SODIUM CHLORIDE WATER SODIUM PHOSPHATE, DIBASIC, ANHYDROUS SODIUM PHOSPHATE, MONOBASIC, MONOHYDRATE ARANESP darbepoetin alfa DARBEPOETIN ALFA DARBEPOETIN ALFA POLYSORBATE 80 SODIUM CHLORIDE WATER SODIUM PHOSPHATE, DIBASIC, ANHYDROUS SODIUM PHOSPHATE, MONOBASIC, MONOHYDRATE ARANESP darbepoetin alfa DARBEPOETIN ALFA DARBEPOETIN ALFA POLYSORBATE 80 SODIUM CHLORIDE WATER SODIUM PHOSPHATE, DIBASIC, ANHYDROUS SODIUM PHOSPHATE, MONOBASIC, MONOHYDRATE ARANESP darbepoetin alfa DARBEPOETIN ALFA DARBEPOETIN ALFA POLYSORBATE 80 SODIUM CHLORIDE WATER SODIUM PHOSPHATE, DIBASIC, ANHYDROUS SODIUM PHOSPHATE, MONOBASIC, MONOHYDRATE ARANESP darbepoetin alfa DARBEPOETIN ALFA DARBEPOETIN ALFA POLYSORBATE 80 SODIUM CHLORIDE WATER SODIUM PHOSPHATE, DIBASIC, ANHYDROUS SODIUM PHOSPHATE, MONOBASIC, MONOHYDRATE ARANESP darbepoetin alfa DARBEPOETIN ALFA DARBEPOETIN ALFA POLYSORBATE 80 SODIUM CHLORIDE WATER SODIUM PHOSPHATE, DIBASIC, ANHYDROUS SODIUM PHOSPHATE, MONOBASIC, MONOHYDRATE ARANESP darbepoetin alfa DARBEPOETIN ALFA DARBEPOETIN ALFA POLYSORBATE 80 SODIUM CHLORIDE WATER SODIUM PHOSPHATE, DIBASIC, ANHYDROUS SODIUM PHOSPHATE, MONOBASIC, MONOHYDRATE ARANESP darbepoetin alfa DARBEPOETIN ALFA DARBEPOETIN ALFA POLYSORBATE 80 SODIUM CHLORIDE WATER SODIUM PHOSPHATE, DIBASIC, ANHYDROUS SODIUM PHOSPHATE, MONOBASIC, MONOHYDRATE ARANESP darbepoetin alfa DARBEPOETIN ALFA DARBEPOETIN ALFA POLYSORBATE 80 SODIUM CHLORIDE WATER SODIUM PHOSPHATE, DIBASIC, ANHYDROUS SODIUM PHOSPHATE, MONOBASIC, MONOHYDRATE'],
#   'ingredients': ['darbepoetin alfa',
#    'Aranesp',
#    'sodium phosphate, monobasic, anhydrous',
#    'sodium phosphate',
#    'MONOHYDRATE',
#    'polysorbates']},
#  {'name': 'Aranelle',
#   'alternative_names': ['aranelle (birth control)',
#    'ethinyl-estradiol-norethindrone',
#    'ethinyl estradiol and norethindrone (birth control)'],
#   'drug_classes': ['Contraceptives', 'Sex hormone combinations'],
#   'uses': ['Acne Vulgaris', 'Contraceptive methods'],
#   'status': 'Prescription only',
#   'generic_name': 'ethinyl-estradiol-norethindrone',
#   'spl_product_data_elements': ['Aranelle norethindrone and ethinyl estradiol Aranelle norethindrone and ethinyl estradiol NORETHINDRONE NORETHINDRONE ETHINYL ESTRADIOL ETHINYL ESTRADIOL D&C YELLOW NO. 10 ALUMINUM LAKE LACTOSE MONOHYDRATE MAGNESIUM STEARATE STARCH, CORN light yellow b;341 Aranelle norethindrone and ethinyl estradiol NORETHINDRONE NORETHINDRONE ETHINYL ESTRADIOL ETHINYL ESTRADIOL LACTOSE MONOHYDRATE MAGNESIUM STEARATE STARCH, CORN b;342 Inert Inert ANHYDROUS LACTOSE FD&C YELLOW NO. 6 MAGNESIUM STEARATE MICROCRYSTALLINE CELLULOSE STARCH, CORN peach b;343'],
#   'ingredients': ['magnesium',
#    'starch',
#    'ethinyl estradiol and norethindrone',
#    'norethindrone',
#    'ethinyl estradiol',
#    'nitric oxide',
#    'Stearates']},
#  {'name': 'Aralen Phosphate',
#   'alternative_names': ['aralen phosphate', 'chloroquine'],
#   'drug_classes': ['Amebicides', 'Antimalarial quinolines'],
#   'uses': ['bite injury',
#    'Malaria',
#    'Amebiasis',
#    'Communicable Diseases',
#    'Muscle strain',
#    'Disease'],
#   'status': 'Discontinued',
#   'generic_name': 'chloroquine',
#   'spl_product_data_elements': ['Chloroquine Phosphate Chloroquine Phosphate CHLOROQUINE PHOSPHATE CHLOROQUINE SILICON DIOXIDE ANHYDROUS DIBASIC CALCIUM PHOSPHATE HYPROMELLOSES MAGNESIUM STEARATE CELLULOSE, MICROCRYSTALLINE POLYETHYLENE GLYCOL POLYSORBATE 80 STARCH, CORN SODIUM STARCH GLYCOLATE TYPE A POTATO TITANIUM DIOXIDE White ROUND CN500'],
#   'ingredients': ['sodium starch glycolate type a corn',
#    'starch',
#    'chloroquine phosphate',
#    'cellulose',
#    'Stearates',
#    'anhydrous dextrose',
#    'polysorbates']},
#  {'name': 'Aralast NP',
#   'alternative_names': ['alpha 1-proteinase inhibitor', 'aralast np'],
#   'drug_classes': ['Miscellaneous respiratory agents'],
#   'uses': ['Malnutrition',
#    'alpha 1-Antitrypsin Deficiency',
#    'Pathological accumulation of air in tissues',
#    'Tissue damage',
#    'Disease Progression'],
#   'status': 'Prescription only',
#   'generic_name': 'alpha 1-proteinase inhibitor',
#   'ingredients': []},
#  {'name': 'Arakoda',
#   'alternative_names': ['arakoda', 'tafenoquine'],
#   'drug_classes': ['Antimalarial quinolines'],
#   'uses': ['bite injury', 'Malaria'],
#   'status': 'Prescription only',
#   'generic_name': 'tafenoquine',
#   'spl_product_data_elements': ['Arakoda Tafenoquine TAFENOQUINE TAFENOQUINE MAGNESIUM STEARATE MANNITOL MICROCRYSTALLINE CELLULOSE HYPROMELLOSE, UNSPECIFIED FERRIC OXIDE RED POLYETHYLENE GLYCOL, UNSPECIFIED TITANIUM DIOXIDE Dark TQ100'],
#   'ingredients': ['Glycol', 'Stearates', 'tafenoquine', 'ferric oxide']},
#  {'name': 'Bivigam',
#   'alternative_names': ['immune-globulin-intravenous',
#    'bivigam (igiv)',
#    'immune globulin (igiv)'],
#   'drug_classes': ['Immune globulins'],
#   'uses': ['Mucocutaneous Lymph Node Syndrome',
#    'Thrombocytopenic purpura',
#    'Primary immune deficiency disorder',
#    'Injection of therapeutic agent',
#    'Aneurysm',
#    'Infections of musculoskeletal system'],
#   'status': 'Prescription only',
#   'generic_name': 'immune-globulin-intravenous',
#   'spl_product_data_elements': ['BIVIGAM Immune Globulin Intravenous (Human) 10% HUMAN IMMUNOGLOBULIN G HUMAN IMMUNOGLOBULIN G BIVIGAM Immune Globulin Intravenous (Human) 10% HUMAN IMMUNOGLOBULIN G HUMAN IMMUNOGLOBULIN G'],
#   'ingredients': ['immunoglobulins, intravenous',
#    'immunoglobulin G',
#    'Bivigam']},
#  {'name': 'Bivalirudin',
#   'alternative_names': ['bivalirudin', 'angiomax'],
#   'drug_classes': ['Thrombin inhibitors'],
#   'uses': ['Interventional procedure',
#    'Occlusion of artery (disorder)',
#    'Chest Pain',
#    'Thrombus',
#    'Angioplasty'],
#   'status': 'Prescription only',
#   'generic_name': 'bivalirudin',
#   'spl_product_data_elements': ['bivalirudin bivalirudin BIVALIRUDIN BIVALIRUDIN MANNITOL SODIUM HYDROXIDE'],
#   'ingredients': ['bivalirudin']},
#  {'name': 'Blue Gel',
#   'alternative_names': ['menthol topical', 'blue gel'],
#   'drug_classes': ['Topical rubefacient'],
#   'uses': ['Back Pain',
#    'Burn injury',
#    'bite injury',
#    'Scraping',
#    'Sprain',
#    'Arthralgia',
#    'Contusions',
#    'Pruritus',
#    'Incised wound',
#    'Sunburn',
#    'Muscle strain',
#    'Arthritis'],
#   'status': 'Rx and/or OTC',
#   'generic_name': 'menthol topical',
#   'spl_product_data_elements': ['Blue Gel Anesthetic Lidocaine HCl, Tetracaine HCl, Racepinephrine HCl Lidocaine Hydrochloride Lidocaine Lidocaine Hydrochloride Anhydrous Tetracaine Hydrochloride Tetracaine Racepinephrine Hydrochloride Racepinephrine Water Diethylene Glycol Monoethyl Ether Propylene Glycol Hydroxyethyl Cellulose, Unspecified Sodium Metabisulfite Epinephrine Hydrochloride Diazolidinyl Urea Edetate Disodium Anhydrous Methylparaben Propylparaben Sodium Citrate, Unspecified Form Citric Acid Monohydrate Fd&C Yellow No. 5 Fd&C Blue No. 1 label'],
#   'ingredients': ['tetracaine hydrochloride',
#    'tetracaine',
#    'epinephrine',
#    'Blue Gel',
#    'hydrochloride',
#    'citric acid',
#    'lidocaine',
#    'racepinephrine hydrochloride',
#    'lidocaine hydrochloride',
#    'epinephrine hydrochloride',
#    'Sparfosate Sodium']},
#  {'name': 'Blue cohosh',
#   'alternative_names': ['herbal products', 'blue cohosh'],
#   'drug_classes': ['Herbal products'],
#   'uses': ['Digital Arthropathy-Brachydactyly, Familial',
#    'Constipation',
#    'Stomach cramps (finding)',
#    'Pharyngitis',
#    'Seizures',
#    'Herbal Supplements'],
#   'status': 'Unknown',
#   'generic_name': 'herbal products',
#   'ingredients': []},
#  {'name': 'Bloxiverz',
#   'alternative_names': ['neostigmine', 'bloxiverz'],
#   'drug_classes': ['Cholinergic muscle stimulants',
#    'Miscellaneous genitourinary tract agents'],
#   'uses': ['Anesthesia procedures'],
#   'status': 'Prescription only',
#   'generic_name': 'neostigmine',
#   'spl_product_data_elements': ['Bloxiverz neostigmine methylsulfate NEOSTIGMINE METHYLSULFATE NEOSTIGMINE PHENOL SODIUM ACETATE WATER ACETIC ACID SODIUM HYDROXIDE'],
#   'ingredients': ['sodium acetate', 'Bloxiverz', 'neostigmine']},
#  {'name': 'BPO Foaming Cloths',
#   'alternative_names': ['benzoyl-peroxide-topical',
#    'benzoyl peroxide topical',
#    'bpo foaming cloths'],
#   'drug_classes': ['Topical acne agents'],
#   'uses': ['Acne Vulgaris'],
#   'status': 'Over the counter',
#   'generic_name': 'benzoyl-peroxide-topical',
#   'spl_product_data_elements': ['Adapalene and Benzoyl Peroxide Adapalene and Benzoyl Peroxide ADAPALENE ADAPALENE BENZOYL PEROXIDE BENZOYL PEROXIDE CARBOMER HOMOPOLYMER TYPE C DOCUSATE SODIUM EDETATE DISODIUM GLYCERIN LIMONENE, (+)- POLOXAMER 182 POLYSORBATE 80 PROPYLENE GLYCOL WATER SODIUM HYDROXIDE SORBITAN MONOOLEATE'],
#   'ingredients': ['limonene',
#    'benzoyl peroxide',
#    'adapalene',
#    'poloxamer',
#    'monooleate',
#    'sorbitan',
#    'propylene',
#    'polysorbates']},
#  {'name': 'BPO',
#   'alternative_names': ['benzoyl peroxide topical',
#    'benzoyl-peroxide-topical',
#    'bpo'],
#   'drug_classes': ['Topical acne agents'],
#   'uses': ['Acne Vulgaris'],
#   'status': 'Rx and/or OTC',
#   'generic_name': 'benzoyl-peroxide-topical',
#   'spl_product_data_elements': ['Differin Daily Deep Cleanser with BPO benzoyl peroxide Benzoyl Peroxide Benzoyl Peroxide Carboxypolymethylene Lauryl Methacrylate/glycol Dimethacrylate Crosspolymer Sodium C14-16 Olefin Sulfonate Sodium Hydroxide Water Glycerin 051803-P56842-1-Differin-Daily-Deep-Cleanser-4oz-Carton'],
#   'ingredients': ['Differin', 'BPO', 'SODIUM OLEFIN SULFONATE', 'CLEANSER']},
#  ...]

# %%
with open('./jsons/processed_data4.json', 'w') as json_file:
    json.dump(drugs_data, json_file, indent=4)
