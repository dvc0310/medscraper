# %%
import spacy
import scispacy
from scispacy.linking import EntityLinker
import json
import numpy as np
from drug_utils import DataHandler
from tqdm import tqdm
import re

# %%
nlp = spacy.load("en_core_sci_sm")
nlp.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})

# Obtain the linker from the pipeline
linker = nlp.get_pipe("scispacy_linker")

# %%
with open('./jsons/processed_data8.json', 'r', encoding='utf-8') as f:
    drugs_data = json.load(f)

# %%
serious_lst = []
for drug in drugs_data:
    if "serious_effects_list" in drug.keys():
        #print(drug['serious_effects_list'])
        serious_lst.extend(drug['serious_effects_list'])
    if "other_effects" in drug.keys():
        #print(drug['serious_effects_list'])
        serious_lst.extend(drug['serious_effects_list'])

serious_lst = list(set(serious_lst))
serious_lst.sort()
serious_lst[10:]
# Out:
# ['Abnormally hard consistency',
#  'Absent pulse',
#  'Accumulation',
#  'Ache',
#  'Acholic stool',
#  'Acidosis',
#  'Acidosis, Lactic',
#  'Acne Vulgaris',
#  'Actual Negative Coping',
#  'Agitation',
#  'Alcoholic Intoxication',
#  'Alopecia',
#  'Amnesia',
#  'Anorexia',
#  'Anxiety',
#  'Apathy',
#  'Aphasia',
#  'Aphthous Stomatitis',
#  'Arthralgia',
#  'As If Personality',
#  'Asthenia',
#  'BODY ACHE',
#  'Back Pain',
#  'Behavior',
#  'Black Discoloration',
#  'Bladder dysfunction',
#  'Bladder pain',
#  'Blindness',
#  'Blister of skin',
#  'Blistering eruption',
#  'Blood in stool',
#  'Bloodshot eye',
#  'Bloody discharge finding',
#  'Blue lips',
#  'Blurred vision',
#  'Body Weight Changes',
#  'Bone pain',
#  'Bowel problem',
#  'Bradycardia',
#  'Bradykinesia',
#  'Breast size',
#  'Breast tenderness',
#  'Breath Holding',
#  'Breathing abnormally deep',
#  'Broad fingertip',
#  'Bulla',
#  'Burn injury',
#  'Burning sensation',
#  'Burning sensation of skin',
#  'Burns and Wounds',
#  'Cachexia',
#  'Cardiac Arrhythmia',
#  'Cardiomegaly',
#  'Cellulitis',
#  'Chapping of lips',
#  'Chest Pain',
#  'Chest discomfort',
#  'Chest tightness',
#  'Chills',
#  'Choking',
#  'Cholelithiasis',
#  'Cicatrization',
#  'Clammy skin',
#  'Clumsiness',
#  'Coffee ground vomiting',
#  'Cold hands',
#  'Cold sweat',
#  'Colitis',
#  'Color Blindness, Blue',
#  'Comatose',
#  'Combativeness',
#  'Common Cold',
#  'Communicable Diseases',
#  'Completed Suicide',
#  'Confusion',
#  'Congestion',
#  'Consciousness related finding',
#  'Constipation',
#  'Constricting sensation quality',
#  'Controlling (action)',
#  'Contusions',
#  'Coughing',
#  'Crack',
#  'Cushingoid facies',
#  'Cyst of eyelid',
#  'DIFFICULTY THINKING',
#  'Deafness',
#  'Decrease in appetite',
#  'Decreased coordination',
#  'Dehydration',
#  'Delirium',
#  'Delusions',
#  'Depersonalization',
#  'Depressed mood',
#  'Derealization',
#  'Diabetes',
#  'Diaper Rash',
#  'Diarrhea',
#  'Difficult (qualifier value)',
#  'Difficulty moving',
#  'Difficulty passing urine',
#  'Difficulty talking',
#  'Difficulty walking',
#  'Dilated',
#  'Diplopia',
#  'Discharge from eye',
#  'Discoloration of skin',
#  'Discomfort',
#  'Disturbance in thinking',
#  'Disturbed sensory perception',
#  'Dizziness',
#  'Drooling',
#  'Drowsiness',
#  'Dry Eye Syndromes',
#  'Dry cough',
#  'Dry lips (finding)',
#  'Dry skin',
#  'Dull pain',
#  'Dullness',
#  'Dyspepsia',
#  'Dysphoric mood',
#  'Dyspnea',
#  'Earache',
#  'Eczema',
#  'Edema',
#  'Edema of foot (finding)',
#  'Encounter due to problems with hearing',
#  'Endophthalmitis',
#  'Epistaxis',
#  'Eructation',
#  'Erythema',
#  'Exaggerated median tongue furrow',
#  'Exanthema',
#  'Excessive tearing',
#  'Eye irritation',
#  'Eye pain',
#  'Eye problem',
#  'FEVER HIGH (finding)',
#  'Facial Expression',
#  'Facial Hypertrichosis',
#  'Facial Paresis',
#  'Facial cyanosis',
#  'Facial edema',
#  'Facial swelling (finding)',
#  'Fair hair',
#  'Fasting',
#  'Fatigue',
#  'Fatty streaks',
#  'Feeding intolerance',
#  'Feeling nervous',
#  'Feeling tired',
#  'Feels cold',
#  'Feels warm',
#  'Felt faint',
#  'Femoral Fractures',
#  'Fever',
#  'Fissure in skin',
#  'Flatulence',
#  'Flushing',
#  'Focal Infection',
#  'Formication',
#  'Fracture',
#  'Frank hematuria',
#  'Frothy',
#  'Gait, Unsteady',
#  'Gallbladder problem',
#  'Gastric Dilatation',
#  'Gastric ulcer',
#  'General unsteadiness',
#  'Generalized enlarged lymph nodes',
#  'Generalized slowing',
#  'Halitosis',
#  'Hallucinations',
#  'Has difficulty doing (qualifier value)',
#  'Has tingling sensation',
#  'Headache',
#  'Health Problems in Pregnancy',
#  'Health problem 1',
#  'Hearing Loss, Sudden',
#  'Hearing change',
#  'Heart murmur',
#  'Heartburn',
#  'Hematemesis',
#  'Hematochezia',
#  'Hemorrhage',
#  'Hemorrhagic diarrhea',
#  'Herpes Labialis',
#  'Hoarseness',
#  'Hordeolum',
#  'Hot flushes',
#  'Hot skin',
#  'Hunger',
#  'Hurting Pain',
#  'Hyperactive behavior',
#  'Hyperglycemia',
#  'Hypernatremia',
#  'Hypersensitivity',
#  'Hypertensive disease',
#  'Hypertrophy',
#  'Hypertrophy of Breast',
#  'Hyperventilation',
#  'Hypesthesia',
#  'Hypotension',
#  'Icterus',
#  'Illness (finding)',
#  'Impairment of balance',
#  'Incised wound',
#  'Incoherent',
#  'Increased frequency of micturition',
#  'Inflammation',
#  'Influenza-like symptoms',
#  'Injury wounds',
#  'Irregular heart beat',
#  'Irritable Mood',
#  'Irritation (finding)',
#  'Itchiness',
#  'Jaw pain',
#  'Joint stiffness',
#  'Joint swelling',
#  'Kidney problem',
#  'Lacrimation',
#  'Lameness',
#  'Leg cramps',
#  'Lesion',
#  'Lethargy',
#  'Leukorrhea',
#  'Lightening of fetus',
#  'Lightheadedness',
#  'Liver problem',
#  'Loss of coordination',
#  'Loss of facial adipose tissue',
#  'Low Back Pain',
#  'Low Vision',
#  'Lung Problem',
#  'Lupus Vulgaris',
#  'Lymphadenopathy',
#  'Malignant Carcinoid Syndrome',
#  'Mask-like facies',
#  'Mass of body structure',
#  'Mastodynia',
#  'Melena',
#  'Memory impairment',
#  'Meningitis',
#  'Menorrhagia',
#  'Menstruation Disturbances',
#  'Mental Depression',
#  'Mental Status Change',
#  'Mental alertness',
#  'Mental state',
#  'Methemoglobinemia',
#  'Metrorrhagia',
#  'Migraine Disorders',
#  'Mild pain',
#  'Miosis disorder',
#  'Monoparesis of lower limb',
#  'Mood swings',
#  'Much',
#  'Muscle Cramp',
#  'Muscle Rigidity',
#  'Muscle tenderness',
#  'Muscle twitch',
#  'Muscular Atrophy',
#  'Muscular fasciculation',
#  'Muscular stiffness',
#  'Myalgia',
#  'Mydriasis',
#  'Nails, Ingrown',
#  'Nasal congestion (finding)',
#  'Nausea',
#  'Neck Pain',
#  'Neck stiffness',
#  'Neck swelling',
#  'Necrotic debris',
#  'Nerve Pain',
#  'Nervousness',
#  'Neuroleptic Malignant Syndrome',
#  'Nightmares',
#  'Nipple pain',
#  'Noisy Image',
#  'Nyctalopia',
#  'Oozing (Hemorrhage)',
#  'Oral Ulcer',
#  'Osteitis Deformans',
#  'Osteopenia',
#  'Other Gender',
#  'Pain',
#  'Pain in lower limb',
#  'Pain of skin',
#  'Pain, Burning',
#  'Pale feces (finding)',
#  'Pallor',
#  'Palpitations',
#  'Pancreatitis',
#  'Panic',
#  'Paralysed',
#  'Paranoia',
#  'Paresis',
#  'Paresthesia',
#  'Parkinsonian Disorders',
#  'Pass (indicator)',
#  'Peeling of skin',
#  'Pelvic Pain',
#  'Pharyngeal dryness',
#  'Pharyngitis',
#  'Photopsia',
#  'Physical aggression',
#  'Pill Rolling Tremor',
#  'Pimples',
#  'Pink skin',
#  'Pinpoint',
#  "Pituitary-dependent Cushing's disease",
#  'Plaque (lesion)',
#  'Poliosis',
#  'Poor coordination',
#  'Presenile dementia',
#  'Prickling sensation',
#  'Primary gout',
#  'Problem',
#  'Productive Cough',
#  'Pruritus',
#  'Psoriasis',
#  'Pulse irregular',
#  'Puncture wound',
#  'Purpura',
#  'Racing Heartbeats',
#  'Rectal pain',
#  'Red stools',
#  'Redness',
#  'Redness of eye',
#  'Reduced',
#  'Respiratory distress',
#  'Restless sleep',
#  'Retinal Detachment',
#  'Return to Work',
#  'Rhabdomyolysis',
#  'Rhinorrhea',
#  'Rhythm',
#  'Rhythmic',
#  'Rib pain',
#  'Round face',
#  'Scaly rash',
#  'Scleral icterus',
#  'Seasonal Affective Disorder',
#  'Seizures',
#  'Severe (severity modifier)',
#  'Sex Behavior',
#  'Shakes',
#  'Shallow',
#  'Shallow breathing',
#  'Sharp sensation quality',
#  'Shiny',
#  'Shivering',
#  'Shock',
#  'Short stature',
#  'Shoulder Pain',
#  'Sinus pain',
#  'Sitting position',
#  'Skin Ulcer',
#  'Skin Wrinkling',
#  'Skin irritation',
#  'Skin is Irritated',
#  'Skin lesion',
#  'Skin normal color',
#  'Sleep disturbances',
#  'Sleeplessness',
#  'Slow Growing',
#  'Slow respiration',
#  'Sluggish',
#  'Sluggishness',
#  'Slurred speech',
#  'Small fontanelle',
#  'Somnambulism',
#  'Sore Throat',
#  'Sore to touch',
#  'Spasm',
#  'Speech problem',
#  'Stabbing pain',
#  'Stevens-Johnson Syndrome',
#  'Stevens-Johnson Syndrome Toxic Epidermal Necrolysis Spectrum',
#  'Stiffness',
#  'Stinging Sensation',
#  'Stomach ache',
#  'Stomach cramps (finding)',
#  'Stupor',
#  'Sudden infant death syndrome',
#  'Suicide',
#  'Sunburn',
#  'Sunken eyes',
#  'Superficial abrasion',
#  'Suspicious behavior (finding)',
#  'Swallowing problem',
#  'Sweating',
#  'Swelling',
#  'Swelling of eyelid',
#  'Swelling of skin',
#  'Swollen Lymph Node',
#  'Symptoms',
#  'Syncope',
#  'Tachycardia',
#  'Tarry',
#  'Taste, Metallic',
#  'Tenderness of gums',
#  'Tension',
#  'Tetany',
#  'Thickened',
#  'Thinness',
#  'Throbbing pain',
#  'Thrombus',
#  'Thyroid Alteration',
#  'Tic disorder',
#  'Tinnitus',
#  'Toothache',
#  'Toxic effect',
#  'Traumatic AND/OR non-traumatic injury',
#  'Traumatic injection site',
#  'Trembling',
#  'Tremor',
#  'Tremor of hands',
#  'Tremor, Muscle',
#  'Trismus',
#  'Tunnel visual field constriction',
#  'Ulcer',
#  'Unable to concentrate',
#  'Unconscious State',
#  'Unresponsiveness',
#  'Upset stomach',
#  'Urticaria',
#  'Uterine hemorrhage',
#  'Vaginal Discharge',
#  'Vaginal Hemorrhage',
#  'Vaginal Yeast Infections',
#  'Vaginal irritation',
#  'Vertigo',
#  'Visual Impairment',
#  'Vitality',
#  'Vitreous floaters',
#  'Voice changes due to male physical maturation',
#  'Vomiting',
#  'Warm skin',
#  'Watery diarrhea',
#  'Watery eyes',
#  'Weakness',
#  'Weight Gain',
#  'Weight Loss',
#  'Welts',
#  'Wheezing',
#  'Writhing movements',
#  'Yawning',
#  'You',
#  'anaphylaxis',
#  'blemishes',
#  'blotchy',
#  'breast discomfort',
#  'ear congestion',
#  'excitable',
#  'exercise induced',
#  'eyelid irritation',
#  'feeling dizzy',
#  'gastric distention',
#  'giddy mood',
#  'head congestion',
#  'irregular bleeding',
#  'lip smacking',
#  'nipple discharge',
#  'no longer in use',
#  'pustule',
#  'red skin lesion',
#  'redness of eyelid',
#  'side pain',
#  'skin bump',
#  'sour stomach',
#  'spells (neurological symptom)',
#  'stomach fullness',
#  'vaginal bleeding irregular',
#  'yellow eyes']

# %%
import pandas as pd

file_path = 'CTCAE_v5.0.xlsx'

# Load the Excel file
df = pd.read_excel(file_path)

# Display the first few rows of the dataframe
df.head()
# Out:
#    MedDRA Code                            MedDRA SOC  \
# 0     10002272  Blood and lymphatic system disorders
# 1     10005329  Blood and lymphatic system disorders
# 2     10048580  Blood and lymphatic system disorders
# 3     10013442  Blood and lymphatic system disorders
# 4     10014950  Blood and lymphatic system disorders
#
#                                           CTCAE Term  \
# 0                                             Anemia
# 1  Blood and lymphatic system disorders - Other, ...
# 2                           Bone marrow hypocellular
# 3             Disseminated intravascular coagulation
# 4                                       Eosinophilia
#
#                                           Grade 1     \
# 0  Hemoglobin (Hgb) <LLN - 10.0 g/dL; <LLN - 6.2 ...
# 1  Asymptomatic or mild symptoms; clinical or dia...
# 2  Mildly hypocellular or <=25% reduction from no...
# 3                                                  -
# 4                                 >ULN and >Baseline
#
#                                           Grade 2     \
# 0  Hgb <10.0 - 8.0 g/dL; <6.2 - 4.9 mmol/L; <100 ...
# 1  Moderate; minimal, local or noninvasive interv...
# 2  Moderately hypocellular or >25 - <50% reductio...
# 3               Laboratory findings with no bleeding
# 4                                                  -
#
#                                           Grade 3     \
# 0  Hgb <8.0 g/dL; <4.9 mmol/L; <80 g/L; transfusi...
# 1  Severe or medically significant but not immedi...
# 2  Severely hypocellular or >50 - <=75% reduction...
# 3                   Laboratory findings and bleeding
# 4                                 Steroids initiated
#
#                                           Grade 4    Grade 5     \
# 0  Life-threatening consequences; urgent interven...      Death
# 1  Life-threatening consequences; urgent interven...      Death
# 2        Aplastic persistent for longer than 2 weeks      Death
# 3  Life-threatening consequences; urgent interven...      Death
# 4                                                  -          -
#
#                                           Definition Navigational Note  \
# 0  A disorder characterized by a reduction in the...               NaN
# 1                                                  -               NaN
# 2  A disorder characterized by the inability of t...               NaN
# 3  A disorder characterized by systemic pathologi...               NaN
# 4  A disorder characterized by laboratory test re...               NaN
#
#            CTCAE v5.0 Change
# 0  Clarification: Definition
# 1     Clarification: Grade 3
# 2                        NaN
# 3                        NaN
# 4             Addition: Term

# %%
unique = pd.unique(df['CTCAE Term'])
unique = list(unique)

# %%
import string
def preprocess(text_list):
    """
    Preprocess a list of text items: lowercase, remove punctuation, and lemmatize.
    """
    preprocessed_list = []
    for text in text_list:
        # Lowercase
        text = text.lower()
        # Remove punctuation
        text = text.translate(str.maketrans('', '', string.punctuation))
        preprocessed_list.append(text)
    return preprocessed_list

# %%
def get_umls_terms_with_mappings(terms, nlp):
    umls_to_original = {}
    umls_terms_list = []
    for term in terms:
        doc = nlp(term)
        for entity in doc.ents:
            for cui, _ in entity._.umls_ents:
                # Append to the list as tuples
                umls_terms_list.append((cui, term))
                # Add to the dictionary
                umls_to_original.setdefault(cui, []).append(term)

    return umls_terms_list, umls_to_original

# Get UMLS terms and their mappings
umls_terms_list, umls_mappings = get_umls_terms_with_mappings(unique, nlp)

# %%
import spacy
import scispacy
from sklearn.metrics.pairwise import cosine_similarity
# ... other necessary imports ...

umls_terms, umls_mappings = get_umls_terms_with_mappings(unique, nlp)
side_effects = serious_lst

# Convert terms to vectors
ctcae_vectors = [nlp(term).vector for term in tqdm(umls_terms)]
side_effect_vectors = [nlp(term).vector for term in tqdm(side_effects)]

# Initialize a dictionary to store mappings
# Initialize a dictionary to store the reverse mappings
side_effect_to_ctcae_mappings = {}

# Calculate similarities and map terms
for i, side_effect_vec in tqdm(enumerate(side_effect_vectors), desc="Processing Side Effects"):
    similarities = cosine_similarity([side_effect_vec], ctcae_vectors)
    
    # Find the index of the highest similarity score
    best_match_index = similarities.argmax()
    best_match_score = similarities[0][best_match_index]

    # Map the side effect to the best matching CTCAE term
    side_effect = side_effects[i]
    best_matching_ctcae_term = umls_terms[best_match_index]
    
    side_effect_to_ctcae_mappings[side_effect] = {
        'ctcae_term': best_matching_ctcae_term,
        'similarity_score': best_match_score
    }

# Evaluate and refine mappings
# Here you can print the mappings or perform further analysis
for side_effect, mapping_info in side_effect_to_ctcae_mappings.items():
    print(f"{side_effect} -> {mapping_info['ctcae_term']} (Score: {mapping_info['similarity_score']})")
# Out:
# 100%|██████████| 837/837 [01:36<00:00,  8.64it/s]
# 100%|██████████| 485/485 [00:52<00:00,  9.24it/s]
# Processing Side Effects: 485it [00:01, 394.29it/s]
# 1/3 meter (distance vision finding) -> Blurred vision (Score: 0.4482669234275818)
# Abdomen distended -> Abdominal distension (Score: 0.5908830165863037)
# Abdominal Pain -> Abdominal pain (Score: 0.8832767009735107)
# Abdominal bloating -> Abdominal pain (Score: 0.8805053234100342)
# Abnormal -> Hair texture abnormal (Score: 0.5068145394325256)
# Abnormal behavior -> Hair texture abnormal (Score: 0.48100802302360535)
# Abnormal breathing -> Movements involuntary (Score: 0.5380785465240479)
# Abnormal color -> Hair color changes (Score: 0.7408782839775085)
# Abnormal coordination -> Movements involuntary (Score: 0.41915708780288696)
# Abnormal sternal ossification -> Nipple deformity (Score: 0.5942028760910034)
# Abnormally hard consistency -> Hair texture abnormal (Score: 0.367364764213562)
# Absent pulse -> Electrocardiogram T wave abnormal (Score: 0.5007792711257935)
# Accumulation -> Concentration impairment (Score: 0.5282284617424011)
# Ache -> Thrush (Score: 0.2810570299625397)
# Acholic stool -> Fecal incontinence (Score: 0.5825943946838379)
# Acidosis -> Acidosis (Score: 1.0000001192092896)
# Acidosis, Lactic -> Acidosis (Score: 0.784635066986084)
# Acne Vulgaris -> Eczema (Score: 0.6444665193557739)
# Actual Negative Coping -> Anxiety (Score: 0.5893059968948364)
# Agitation -> Agitation (Score: 1.0000001192092896)
# Alcoholic Intoxication -> Pancreatitis (Score: 0.6180058717727661)
# Alopecia -> Alopecia (Score: 1.0)
# Amnesia -> Amnesia (Score: 1.0)
# Anorexia -> Anorexia (Score: 1.0)
# Anxiety -> Anxiety (Score: 1.0)
# Apathy -> Depression (Score: 0.7684398889541626)
# Aphasia -> Amnesia (Score: 0.6262493133544922)
# Aphthous Stomatitis -> Diarrhea (Score: 0.6282328367233276)
# Arthralgia -> Arthralgia (Score: 1.000000238418579)
# As If Personality -> Personality change (Score: 0.7508341670036316)
# Asthenia -> Myalgia (Score: 0.7163083553314209)
# eyelid irritation -> Skin ulceration (Score: 0.6401103734970093)
# feeling dizzy -> Pleuritic pain (Score: 0.5630638599395752)
# gastric distention -> Gastric perforation (Score: 0.770439863204956)
# giddy mood -> Anorgasmia (Score: 0.6272643208503723)
# head congestion -> Intraoperative head and neck injury (Score: 0.6930166482925415)
# irregular bleeding -> Urostomy site bleeding (Score: 0.6123265624046326)
# lip smacking -> Nipple deformity (Score: 0.5368269681930542)
# nipple discharge -> Vaginal discharge (Score: 0.7523062229156494)
# no longer in use -> General disorders and administration site conditions - Other, specify (Score: 0.42138999700546265)
# pustule -> Skin hyperpigmentation (Score: 0.5268790125846863)
# red skin lesion -> Skin hyperpigmentation (Score: 0.562635064125061)
# redness of eyelid -> Skin hyperpigmentation (Score: 0.6408116817474365)
# side pain -> Pleuritic pain (Score: 0.7290388941764832)
# skin bump -> Skin hyperpigmentation (Score: 0.5753247737884521)
# sour stomach -> Gastric ulcer (Score: 0.44444403052330017)
# spells (neurological symptom) -> Flu like symptoms (Score: 0.546831488609314)
# stomach fullness -> Stomach pain (Score: 0.6458065509796143)
# vaginal bleeding irregular -> Vaginal perforation (Score: 0.7544639110565186)
# yellow eyes -> Watering eyes (Score: 0.6955603361129761)

# %%
with open('./jsons/processed_data8.json', 'r', encoding='utf-8') as f:
    drugs_data = json.load(f)

# %%
# Preprocess 'serious_effects_list' and 'other_effects' in drugs_data
for drug in tqdm(drugs_data):
    drug['serious_effects_list'] = [preprocess(effect) for effect in drug['serious_effects_list']]
    drug['other_effects'] = [preprocess(effect) for effect in drug['other_effects']]

# Use the mapping to find corresponding CTCAE terms
for drug in tqdm(drugs_data):
    drug['serious_effects_list'] = [side_effect_to_ctcae_mappings.get(effect, {'ctcae_term': None})['ctcae_term'] 
                                      for effect in drug['serious_effects_list']]
    drug['other_effects'] = [side_effect_to_ctcae_mappings.get(effect, {'ctcae_term': None})['ctcae_term'] 
                                    for effect in drug['other_effects']]
# Out:
# 100%|██████████| 7878/7878 [00:04<00:00, 1904.32it/s]
#   0%|          | 0/7878 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 8
#       6 # Use the mapping to find corresponding CTCAE terms
#       7 for drug in tqdm(drugs_data):
# ----> 8     drug['serious_effects_list'] = [side_effect_to_ctcae_mappings.get(effect, {'ctcae_term': None})['ctcae_term']
#       9                                       for effect in drug['serious_effects_list']]
#      10     drug['other_effects'] = [side_effect_to_ctcae_mappings.get(effect, {'ctcae_term': None})['ctcae_term']
#      11                                     for effect in drug['other_effects']]
#
# Cell In[35], line 8, in <listcomp>(.0)
#       6 # Use the mapping to find corresponding CTCAE terms
#       7 for drug in tqdm(drugs_data):
# ----> 8     drug['serious_effects_list'] = [side_effect_to_ctcae_mappings.get(effect, {'ctcae_term': None})['ctcae_term']
#       9                                       for effect in drug['serious_effects_list']]
#      10     drug['other_effects'] = [side_effect_to_ctcae_mappings.get(effect, {'ctcae_term': None})['ctcae_term']
#      11                                     for effect in drug['other_effects']]
#
# TypeError: unhashable type: 'list'
