# %%
import spacy
import scispacy
from scispacy.linking import EntityLinker

# %%
nlp = spacy.load("en_core_sci_sm")
nlp.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})

# Obtain the linker from the pipeline
linker = nlp.get_pipe("scispacy_linker")
# Out:
# c:\Users\sjchu\.pyenv\pyenv-win\versions\3.9.6\lib\site-packages\spacy\language.py:2141: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]

# %%
import json


def process_drug_uses(drugs_data):
    # Initialize dictionary for drug uses
    drug_uses_dict = {}
    relevant_types = {"T047", "T048", "T184", "T037", "T046", "T061", "T060"}
    semantic_type_descriptions = {
        "T047": "Disease or Syndrome",
        "T184": "Sign or Symptom",
        "T037": "Injury or Poisoning",
        "T046": "Pathologic Function",
        "T061": "Therapeutic or Preventive Procedure",
        "T060": "Diagnostic Procedure",
        "T048": "Mental or Behavioral Dysfunction"
    }
    # Iterate over each drug in the data
    for drug in drugs_data:
        drug_name = drug['name']
        conditions_and_diseases = []
        
        # Process each paragraph in the 'uses' list for this drug
        for uses_text in drug['uses']:
            # Process the uses text with the NLP model
            doc = nlp(uses_text)

            # Iterate over the entities and link them to UMLS
            for ent in doc.ents:
                kb_ents = ent._.kb_ents
                if kb_ents:
                    cui = kb_ents[0][0]  # Get the top CUI
                    umls_entity = linker.kb.cui_to_entity[cui]

                    # Check if the UMLS entity has a relevant semantic type
                    if any(st in relevant_types for st in umls_entity.types):
                        types = [semantic_type_descriptions[type_code] for type_code in umls_entity.types]
                        print(f"Types for {umls_entity.canonical_name}:{types}")
                        conditions_and_diseases.append(umls_entity.canonical_name)



        # Remove duplicates and add to the dictionary
        drug_uses_dict[drug_name] = list(set(conditions_and_diseases))

    return drug_uses_dict

# Load the JSON data
json_file_path = 'outputtest.json'  # Update this to your JSON file path
with open(json_file_path, 'r', encoding='utf-8') as file:
    drugs_data = json.load(file)

# Process the drug uses
drugs_uses_dict = process_drug_uses(drugs_data)

# Output the results
for drug, uses in drugs_uses_dict.items():
    print(f"{drug}: {uses}")
# Out:
# Types for Ulcerative Colitis:['Disease or Syndrome']
# Types for Ulcerative Colitis:['Disease or Syndrome']
# Types for Ulcerative Colitis:['Disease or Syndrome']
# Types for Ulcerative Colitis:['Disease or Syndrome']
# Types for Rheumatoid Arthritis:['Disease or Syndrome']
# Types for Arthritis:['Disease or Syndrome']
# Types for Cancer Pain:['Sign or Symptom']
# Types for Acne Vulgaris:['Disease or Syndrome']
# Types for Acne Vulgaris:['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Thrombus:['Pathologic Function']
# Types for Congenital Thrombotic Thrombocytopenic Purpura:['Disease or Syndrome']
# Types for Infusion procedures:['Therapeutic or Preventive Procedure']
# Types for Intravenous infusion procedures:['Therapeutic or Preventive Procedure']
# Types for Blood Coagulation Disorders:['Disease or Syndrome']
# Types for Anemia, Hemolytic:['Disease or Syndrome']
# Types for Headache:['Sign or Symptom']
# Types for Abdominal Pain:['Sign or Symptom']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Attention deficit hyperactivity disorder:['Psychiatric disorder']
# Types for Attention deficit hyperactivity disorder:['Psychiatric disorder']
# Types for Narcolepsy:['Disease or Syndrome']
# Types for Obesity:['Disease or Syndrome']
# Types for Therapeutic procedure:['Therapeutic or Preventive Procedure']
# Types for Attention deficit hyperactivity disorder:['Psychiatric disorder']
# Types for Contraceptive methods:['Therapeutic or Preventive Procedure']
# Types for Mycoses:['Disease or Syndrome']
# Types for Mycoses:['Disease or Syndrome']
# Types for Hemophilia A:['Disease or Syndrome']
# Types for Hemorrhage:['Pathologic Function']
# Types for Hemophilia A:['Disease or Syndrome']
# Types for Hemophilia A:['Disease or Syndrome']
# Types for von Willebrand Disease:['Disease or Syndrome']
# Types for Asthma:['Disease or Syndrome']
# Types for Asthma:['Disease or Syndrome']
# Types for Asthma:['Disease or Syndrome']
# Types for Inflammation:['Pathologic Function']
# Types for Inflammation:['Pathologic Function']
# Types for Dyspnea:['Sign or Symptom']
# Types for Nausea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Pharmacotherapy:['Therapeutic or Preventive Procedure']
# Types for Nausea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Pharmacotherapy:['Therapeutic or Preventive Procedure']
# Types for Vomiting:['Sign or Symptom']
# Types for Erectile dysfunction:['Disease or Syndrome']
# Types for Erectile dysfunction:['Disease or Syndrome']
# Types for Benign Prostatic Hyperplasia:['Pathologic Function']
# Types for Pulmonary arterial hypertension:['Disease or Syndrome']
# Types for Erectile dysfunction:['Disease or Syndrome']
# Types for Pulmonary arterial hypertension:['Disease or Syndrome']
# Types for Acne Vulgaris:['Disease or Syndrome']
# Types for Cellulitis:['Disease or Syndrome']
# Types for Nausea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Pharmacotherapy:['Therapeutic or Preventive Procedure']
# Types for Nausea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Injection of therapeutic agent:['Therapeutic or Preventive Procedure']
# Types for Nausea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Azulfidine: ['Rheumatoid Arthritis', 'Arthritis', 'Ulcerative Colitis']
# Abstral: ['Cancer Pain']
# Aczone: ['Hypersensitivity', 'Acne Vulgaris']
# Adzynma: ['Blood Coagulation Disorders', 'Intravenous infusion procedures', 'Congenital Thrombotic Thrombocytopenic Purpura', 'Headache', 'Anemia, Hemolytic', 'Thrombus', 'Infusion procedures', 'Digital Arthropathy-Brachydactyly, Familial', 'Abdominal Pain']
# Adzenys XR-ODT: ['Therapeutic procedure', 'Obesity', 'Narcolepsy', 'Attention deficit hyperactivity disorder']
# AfterPill: ['Contraceptive methods']
# Aftate (Topical): ['Mycoses']
# Afstyla (recombinant): ['von Willebrand Disease', 'Hemophilia A', 'Hemorrhage']
# Airsupra (inhalation): ['Asthma']
# Airsupra: ['Dyspnea', 'Inflammation']
# Akynzeo for (injection): ['Pharmacotherapy', 'Nausea', 'Vomiting']
# Alyq: ['Erectile dysfunction', 'Benign Prostatic Hyperplasia', 'Pulmonary arterial hypertension']
# Amzeeq: ['Cellulitis', 'Acne Vulgaris']
# Anzemet (Oral): ['Pharmacotherapy', 'Nausea', 'Vomiting']
# Anzemet (Intravenous): ['Injection of therapeutic agent', 'Nausea', 'Vomiting']

# %%
def process_drug(drug, nlp, linker):
    drug_name = drug['name']
    conditions_and_diseases = []
    
    # Process each paragraph in the 'side_effects' list for this drug
    for uses_text in drug['uses']:
        # Process the uses text with the NLP model
        doc = nlp(uses_text)

        # Iterate over the entities and link them to UMLS
        for ent in doc.ents:
            kb_ents = ent._.kb_ents
            if kb_ents:
                cui = kb_ents[0][0]  # Get the top CUI
                umls_entity = linker.kb.cui_to_entity[cui]

                # Check if the UMLS entity has a relevant semantic type
                relevant_types = {"T047", "T048", "T184", "T037", "T046", "T061", "T060"}
                if any(st in relevant_types for st in umls_entity.types):
                    conditions_and_diseases.append(umls_entity.canonical_name)

    # Remove duplicates
    return drug_name, list(set(conditions_and_diseases))

# %%
# Load the JSON data
json_file_path = 'outputtest.json'  # Update this to your JSON file path
with open(json_file_path, 'r', encoding='utf-8') as file:
    drugs_data = json.load(file)
    
# Loop through the drugs and process only Melatonin
for drug in drugs_data:
    if drug['name'] == 'Melatonin':
        drug_name, conditions_and_diseases = process_drug(drug, nlp, linker)
        print(f"{drug_name} is used for: {conditions_and_diseases}")
        break  # Stop the loop after finding Melatonin
# Out:
# Melatonin is used for: ['Cancer Therapeutic Procedure', 'Sleeplessness', 'Sleep disturbances', 'Jet Lag Syndrome', 'Sleep Disorders']

# %%
import json

def process_side_effects(drugs_data, nlp, linker):
    # Initialize dictionary for drug uses
    drug_uses_dict = {}
    
    # Iterate over each drug in the data
    for drug in drugs_data:
        drug_name, conditions_and_diseases = process_drug(drug, nlp, linker)
        drug_uses_dict[drug_name] = conditions_and_diseases

    return drug_uses_dict

# Load the JSON data
json_file_path = 'outputtest.json'  # Update this to your JSON file path
with open(json_file_path, 'r', encoding='utf-8') as file:
    drugs_data = json.load(file)

# Process the drug uses
drugs_uses_dict = process_side_effects(drugs_data)

# Output the results
for drug, uses in drugs_uses_dict.items():
    print(f"{drug}: {uses}")
# Out:
# Types for Generalized essential telangiectasia (disorder):['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Urticaria:['Disease or Syndrome']
# Types for Edema:['Pathologic Function']
# Types for Fever:['Sign or Symptom']
# Types for Pharyngitis:['Disease or Syndrome']
# Types for Eye Burns:['Injury or Poisoning']
# Types for Pain of skin:['Sign or Symptom']
# Types for Exanthema:['Sign or Symptom']
# Types for Adverse reaction to drug:['Pathologic Function']
# Types for Exanthema:['Sign or Symptom']
# Types for Fever:['Sign or Symptom']
# Types for Swollen Lymph Node:['Sign or Symptom']
# Types for Myalgia:['Sign or Symptom']
# Types for Asthenia:['Sign or Symptom']
# Types for Contusions:['Injury or Poisoning']
# Types for Infections of musculoskeletal system:['Disease or Syndrome']
# Types for Infection:['Pathologic Function']
# Types for Communicable Diseases:['Disease or Syndrome']
# Types for Fever:['Sign or Symptom']
# Types for Chills:['Sign or Symptom']
# Types for Pharyngitis:['Disease or Syndrome']
# Types for Oral Ulcer:['Disease or Syndrome']
# Types for Contusions:['Injury or Poisoning']
# Types for Hemorrhage:['Pathologic Function']
# Types for Chest discomfort:['Sign or Symptom']
# Types for Wheezing:['Sign or Symptom']
# Types for Dry cough:['Sign or Symptom']
# Types for Fever:['Sign or Symptom']
# Types for Headache:['Sign or Symptom']
# Types for Exanthema:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Exanthema:['Sign or Symptom']
# Types for Nausea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Cushingoid facies:['Sign or Symptom']
# Types for Edema:['Pathologic Function']
# Types for Anorexia:['Disease or Syndrome']
# Types for Abdominal Pain:['Sign or Symptom']
# Types for Icterus:['Sign or Symptom']
# Types for Nausea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Upset stomach:['Sign or Symptom']
# Types for Anorexia:['Disease or Syndrome']
# Types for Headache:['Sign or Symptom']
# Types for Exanthema:['Sign or Symptom']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Generalized essential telangiectasia (disorder):['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Urticaria:['Disease or Syndrome']
# Types for Dyspnea:['Sign or Symptom']
# Types for Edema:['Pathologic Function']
# Types for Blue lips:['Sign or Symptom']
# Types for Sighing respiration:['Sign or Symptom']
# Types for Shallow breathing:['Sign or Symptom']
# Types for Confusion:['Mental or Behavioral Dysfunction']
# Types for Nausea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Anorexia:['Disease or Syndrome']
# Types for Dizziness:['Sign or Symptom']
# Types for Fatigue:['Sign or Symptom']
# Types for Asthenia:['Sign or Symptom']
# Types for Malignant Carcinoid Syndrome:['Disease or Syndrome']
# Types for Agitation:['Sign or Symptom']
# Types for Hallucinations:['Mental or Behavioral Dysfunction']
# Types for Fever:['Sign or Symptom']
# Types for Muscular stiffness:['Sign or Symptom']
# Types for Nausea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Diarrhea:['Sign or Symptom']
# Types for Malnutrition:['Disease or Syndrome']
# Types for Headache:['Sign or Symptom']
# Types for Dizziness:['Sign or Symptom']
# Types for Fatigue:['Sign or Symptom']
# Types for Constipation:['Sign or Symptom']
# Types for Nausea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Edema:['Pathologic Function']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Generalized essential telangiectasia (disorder):['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Urticaria:['Disease or Syndrome']
# Types for Edema:['Pathologic Function']
# Types for Methemoglobinemia:['Disease or Syndrome']
# Types for Septicemia:['Disease or Syndrome']
# Types for Pharyngitis:['Disease or Syndrome']
# Types for Red blood cell disorder:['Disease or Syndrome']
# Types for Back Pain:['Sign or Symptom']
# Types for Fever:['Sign or Symptom']
# Types for Confusion:['Mental or Behavioral Dysfunction']
# Types for Asthenia:['Sign or Symptom']
# Types for Pain:['Sign or Symptom']
# Types for Nausea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Fever:['Sign or Symptom']
# Types for Pharyngitis:['Disease or Syndrome']
# Types for Edema:['Pathologic Function']
# Types for Burning sensation:['Sign or Symptom']
# Types for Pain of skin:['Sign or Symptom']
# Types for Exanthema:['Sign or Symptom']
# Types for Erythema:['Disease or Syndrome']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Exanthema:['Sign or Symptom']
# Types for Urticaria:['Disease or Syndrome']
# Types for Pruritus:['Sign or Symptom']
# Types for Chest Pain:['Sign or Symptom']
# Types for Dyspnea:['Sign or Symptom']
# Types for Lightheadedness:['Sign or Symptom']
# Types for Dizziness:['Sign or Symptom']
# Types for Nausea:['Sign or Symptom']
# Types for Syncope:['Sign or Symptom']
# Types for Headache:['Sign or Symptom']
# Types for Diarrhea:['Sign or Symptom']
# Types for Migraine Disorders:['Disease or Syndrome']
# Types for Abdominal Pain:['Sign or Symptom']
# Types for Nausea:['Sign or Symptom']
# Types for Upper Respiratory Infections:['Disease or Syndrome']
# Types for Dizziness:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Adverse effects:['Pathologic Function']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Generalized essential telangiectasia (disorder):['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Urticaria:['Disease or Syndrome']
# Types for Edema:['Pathologic Function']
# Types for HEART PROBLEM:['Sign or Symptom']
# Types for Dyspnea:['Sign or Symptom']
# Types for Hallucinations:['Mental or Behavioral Dysfunction']
# Types for Abnormal behavior:['Mental or Behavioral Dysfunction']
# Types for Paranoia:['Mental or Behavioral Dysfunction']
# Types for Pain:['Sign or Symptom']
# Types for Seizures:['Sign or Symptom']
# Types for Seizures:['Sign or Symptom']
# Types for Muscular fasciculation:['Sign or Symptom']
# Types for Tic disorder:['Mental or Behavioral Dysfunction']
# Types for Malignant Carcinoid Syndrome:['Disease or Syndrome']
# Types for Agitation:['Sign or Symptom']
# Types for Hallucinations:['Mental or Behavioral Dysfunction']
# Types for Fever:['Sign or Symptom']
# Types for Muscular stiffness:['Sign or Symptom']
# Types for Nausea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Diarrhea:['Sign or Symptom']
# Types for Mood swings:['Mental or Behavioral Dysfunction']
# Types for Anxiety:['Mental or Behavioral Dysfunction']
# Types for Agitation:['Sign or Symptom']
# Types for Nervousness:['Sign or Symptom']
# Types for Sleep disturbances:['Sign or Symptom']
# Types for Abdominal Pain:['Sign or Symptom']
# Types for Nausea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Diarrhea:['Sign or Symptom']
# Types for Constipation:['Sign or Symptom']
# Types for Anorexia:['Disease or Syndrome']
# Types for sexual problem:['Disease or Syndrome']
# Types for Erectile dysfunction:['Disease or Syndrome']
# Types for Headache:['Sign or Symptom']
# Types for Dizziness:['Sign or Symptom']
# Types for Pruritus:['Sign or Symptom']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Generalized essential telangiectasia (disorder):['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Urticaria:['Disease or Syndrome']
# Types for Edema:['Pathologic Function']
# Types for Pain:['Sign or Symptom']
# Types for Pregnancy, Tubal:['Pathologic Function']
# Types for Pregnancy, Tubal:['Pathologic Function']
# Types for Abdominal Pain:['Sign or Symptom']
# Types for Mastodynia:['Sign or Symptom']
# Types for Sore to touch:['Sign or Symptom']
# Types for Nausea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Diarrhea:['Sign or Symptom']
# Types for Headache:['Sign or Symptom']
# Types for Dizziness:['Sign or Symptom']
# Types for Fatigue:['Sign or Symptom']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Generalized essential telangiectasia (disorder):['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Urticaria:['Disease or Syndrome']
# Types for Pruritus:['Sign or Symptom']
# Types for Exanthema:['Sign or Symptom']
# Types for Paresthesia:['Disease or Syndrome']
# Types for Fever:['Sign or Symptom']
# Types for Dizziness:['Sign or Symptom']
# Types for Nausea:['Sign or Symptom']
# Types for Chest tightness:['Sign or Symptom']
# Types for Wheezing:['Sign or Symptom']
# Types for Cold sweat:['Sign or Symptom']
# Types for Lightheadedness:['Sign or Symptom']
# Types for Syncope:['Sign or Symptom']
# Types for Edema:['Pathologic Function']
# Types for Hemorrhage:['Pathologic Function']
# Types for Chest Pain:['Sign or Symptom']
# Types for Lightheadedness:['Sign or Symptom']
# Types for Nausea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Diarrhea:['Sign or Symptom']
# Types for Headache:['Sign or Symptom']
# Types for Dizziness:['Sign or Symptom']
# Types for Arthralgia:['Sign or Symptom']
# Types for Exanthema:['Sign or Symptom']
# Types for Flushing:['Sign or Symptom']
# Types for Erythema:['Disease or Syndrome']
# Types for Fever:['Sign or Symptom']
# Types for Chills:['Sign or Symptom']
# Types for Asthenia:['Sign or Symptom']
# Types for Edema:['Pathologic Function']
# Types for Pruritus:['Sign or Symptom']
# Types for Erythema:['Disease or Syndrome']
# Types for Injection of therapeutic agent:['Therapeutic or Preventive Procedure']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Generalized essential telangiectasia (disorder):['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Urticaria:['Disease or Syndrome']
# Types for Edema:['Pathologic Function']
# Types for Coughing:['Sign or Symptom']
# Types for Wheezing:['Sign or Symptom']
# Types for HEART PROBLEM:['Sign or Symptom']
# Types for Hypertensive disease:['Disease or Syndrome']
# Types for Leg cramps:['Sign or Symptom']
# Types for Constipation:['Sign or Symptom']
# Types for Paresthesia:['Disease or Syndrome']
# Types for Paresis:['Disease or Syndrome']
# Types for Nausea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Abdominal Pain:['Sign or Symptom']
# Types for Anorexia:['Disease or Syndrome']
# Types for Fatigue:['Sign or Symptom']
# Types for Lightheadedness:['Sign or Symptom']
# Types for Arthralgia:['Sign or Symptom']
# Types for Communicable Diseases:['Disease or Syndrome']
# Types for Fever:['Sign or Symptom']
# Types for Chills:['Sign or Symptom']
# Types for Pharyngitis:['Disease or Syndrome']
# Types for BODY ACHE:['Sign or Symptom']
# Types for Fatigue:['Sign or Symptom']
# Types for Anorexia:['Disease or Syndrome']
# Types for Contusions:['Injury or Poisoning']
# Types for Hemorrhage:['Pathologic Function']
# Types for Glaucoma:['Disease or Syndrome']
# Types for Cataract:['Disease or Syndrome']
# Types for Bone pain:['Sign or Symptom']
# Types for Oral Ulcer:['Disease or Syndrome']
# Types for Poliosis:['Disease or Syndrome']
# Types for Headache:['Sign or Symptom']
# Types for Hoarseness:['Sign or Symptom']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Dyspnea:['Sign or Symptom']
# Types for Coughing:['Sign or Symptom']
# Types for Wheezing:['Sign or Symptom']
# Types for Paradoxical bronchospasm:['Pathologic Function']
# Types for Paradoxical bronchospasm:['Pathologic Function']
# Types for HEART PROBLEM:['Sign or Symptom']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Exanthema:['Sign or Symptom']
# Types for Erythema:['Disease or Syndrome']
# Types for Edema:['Pathologic Function']
# Types for Pruritus:['Sign or Symptom']
# Types for Edema:['Pathologic Function']
# Types for Dyspnea:['Sign or Symptom']
# Types for Chest Pain:['Sign or Symptom']
# Types for Infection:['Pathologic Function']
# Types for Communicable Diseases:['Disease or Syndrome']
# Types for Fever:['Sign or Symptom']
# Types for Pain:['Sign or Symptom']
# Types for Chills:['Sign or Symptom']
# Types for Fatigue:['Sign or Symptom']
# Types for Nausea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Mycoses:['Disease or Syndrome']
# Types for Candidiasis:['Disease or Syndrome']
# Types for Adverse effects:['Pathologic Function']
# Types for Candidiasis:['Disease or Syndrome']
# Types for Adrenal gland hypofunction:['Disease or Syndrome']
# Types for Adrenal gland hypofunction:['Disease or Syndrome']
# Types for Fever:['Sign or Symptom']
# Types for Wounds and Injuries:['Injury or Poisoning']
# Types for Communicable Diseases:['Disease or Syndrome']
# Types for Adrenal gland hypofunction:['Disease or Syndrome']
# Types for Adrenal gland hypofunction:['Disease or Syndrome']
# Types for Fatigue:['Sign or Symptom']
# Types for Asthenia:['Sign or Symptom']
# Types for Nausea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Asthenia:['Sign or Symptom']
# Types for Osteoporosis:['Disease or Syndrome']
# Types for Glaucoma:['Disease or Syndrome']
# Types for Cataract:['Disease or Syndrome']
# Types for Headache:['Sign or Symptom']
# Types for Hoarseness:['Sign or Symptom']
# Types for Adverse effects:['Pathologic Function']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Ifosfamide/Methotrexate/Procarbazine protocol:['Therapeutic or Preventive Procedure']
# Types for Tremor:['Sign or Symptom']
# Types for Tremor:['Sign or Symptom']
# Types for Tremor:['Sign or Symptom']
# Types for Tremor:['Sign or Symptom']
# Types for Foreign Bodies:['Injury or Poisoning']
# Types for Tremor:['Sign or Symptom']
# Types for Tremor:['Sign or Symptom']
# Types for Spraying behavior:['Mental or Behavioral Dysfunction']
# Types for Tremor:['Sign or Symptom']
# Types for Molluscum Contagiosum:['Disease or Syndrome']
# Types for Tremor:['Sign or Symptom']
# Types for Cerebral artery atherosclerosis:['Disease or Syndrome']
# Types for Cerebral artery atherosclerosis:['Disease or Syndrome']
# Types for Air-Drying:['Therapeutic or Preventive Procedure']
# Types for Tremor:['Sign or Symptom']
# Types for Tremor:['Sign or Symptom']
# Types for Generalized essential telangiectasia (disorder):['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Urticaria:['Disease or Syndrome']
# Types for Chest Pain:['Sign or Symptom']
# Types for Edema:['Pathologic Function']
# Types for Malignant Carcinoid Syndrome:['Disease or Syndrome']
# Types for Agitation:['Sign or Symptom']
# Types for Hallucinations:['Mental or Behavioral Dysfunction']
# Types for Muscular stiffness:['Sign or Symptom']
# Types for Nausea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Diarrhea:['Sign or Symptom']
# Types for Headache:['Sign or Symptom']
# Types for Fatigue:['Sign or Symptom']
# Types for Erythema:['Disease or Syndrome']
# Types for Upset stomach:['Sign or Symptom']
# Types for Constipation:['Sign or Symptom']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Generalized essential telangiectasia (disorder):['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Urticaria:['Disease or Syndrome']
# Types for Dyspnea:['Sign or Symptom']
# Types for Edema:['Pathologic Function']
# Types for Myocardial Infarction:['Disease or Syndrome']
# Types for Nausea:['Sign or Symptom']
# Types for Sudden Visual Loss:['Sign or Symptom']
# Types for Tinnitus:['Disease or Syndrome']
# Types for Pain:['Sign or Symptom']
# Types for Tissue damage:['Injury or Poisoning']
# Types for Nausea:['Sign or Symptom']
# Types for Chest Pain:['Sign or Symptom']
# Types for Dizziness:['Sign or Symptom']
# Types for Adverse effects:['Pathologic Function']
# Types for Headache:['Sign or Symptom']
# Types for Flushing:['Sign or Symptom']
# Types for Erythema:['Disease or Syndrome']
# Types for Nausea:['Sign or Symptom']
# Types for Upset stomach:['Sign or Symptom']
# Types for Rhinorrhea:['Sign or Symptom']
# Types for Nasal congestion (finding):['Sign or Symptom']
# Types for Myalgia:['Sign or Symptom']
# Types for Back Pain:['Sign or Symptom']
# Types for Pain:['Sign or Symptom']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Generalized essential telangiectasia (disorder):['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Urticaria:['Disease or Syndrome']
# Types for Edema:['Pathologic Function']
# Types for Fever:['Sign or Symptom']
# Types for Pharyngitis:['Disease or Syndrome']
# Types for Eye Burns:['Injury or Poisoning']
# Types for Pain of skin:['Sign or Symptom']
# Types for Exanthema:['Sign or Symptom']
# Types for Adverse reaction to drug:['Pathologic Function']
# Types for Exanthema:['Sign or Symptom']
# Types for Fever:['Sign or Symptom']
# Types for Swollen Lymph Node:['Sign or Symptom']
# Types for Myalgia:['Sign or Symptom']
# Types for Asthenia:['Sign or Symptom']
# Types for Contusions:['Injury or Poisoning']
# Types for Abdominal Pain:['Sign or Symptom']
# Types for Diarrhea:['Sign or Symptom']
# Types for Dizziness:['Sign or Symptom']
# Types for Confusion:['Mental or Behavioral Dysfunction']
# Types for Headache:['Sign or Symptom']
# Types for Pain:['Sign or Symptom']
# Types for Fever:['Sign or Symptom']
# Types for Swollen Lymph Node:['Sign or Symptom']
# Types for Pruritus:['Sign or Symptom']
# Types for Arthralgia:['Sign or Symptom']
# Types for Anorexia:['Disease or Syndrome']
# Types for Abdominal Pain:['Sign or Symptom']
# Types for Fatigue:['Sign or Symptom']
# Types for Pruritus:['Sign or Symptom']
# Types for Icterus:['Sign or Symptom']
# Types for Arthralgia:['Sign or Symptom']
# Types for Influenza:['Disease or Syndrome']
# Types for Chest Pain:['Sign or Symptom']
# Types for Exanthema:['Sign or Symptom']
# Types for Diarrhea:['Sign or Symptom']
# Types for Headache:['Sign or Symptom']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Chest Pain:['Sign or Symptom']
# Types for Discomfort:['Sign or Symptom']
# Types for Lightheadedness:['Sign or Symptom']
# Types for Dizziness:['Sign or Symptom']
# Types for Syncope:['Sign or Symptom']
# Types for Fatigue:['Sign or Symptom']
# Types for Asthenia:['Sign or Symptom']
# Types for Chills:['Sign or Symptom']
# Types for Fever:['Sign or Symptom']
# Types for Agitation:['Sign or Symptom']
# Types for Melena:['Pathologic Function']
# Types for Hemorrhage:['Pathologic Function']
# Types for Edema:['Pathologic Function']
# Types for Burning sensation:['Sign or Symptom']
# Types for Confusion:['Mental or Behavioral Dysfunction']
# Types for Delirium:['Mental or Behavioral Dysfunction']
# Types for Mental Depression:['Mental or Behavioral Dysfunction']
# Types for Diarrhea:['Sign or Symptom']
# Types for Pain:['Sign or Symptom']
# Types for Dizziness:['Sign or Symptom']
# Types for Syncope:['Sign or Symptom']
# Types for Lightheadedness:['Sign or Symptom']
# Types for Hallucinations:['Mental or Behavioral Dysfunction']
# Types for Headache:['Sign or Symptom']
# Types for Urticaria:['Disease or Syndrome']
# Types for Welts:['Sign or Symptom']
# Types for Pruritus:['Sign or Symptom']
# Types for Exanthema:['Sign or Symptom']
# Types for Lethargy:['Sign or Symptom']
# Types for Muscular fasciculation:['Sign or Symptom']
# Types for Nausea:['Sign or Symptom']
# Types for Paresthesia:['Disease or Syndrome']
# Types for Pain:['Sign or Symptom']
# Types for Pain:['Sign or Symptom']
# Types for Pain:['Sign or Symptom']
# Types for Sore to touch:['Sign or Symptom']
# Types for Edema:['Pathologic Function']
# Types for Purpura:['Disease or Syndrome']
# Types for Facial edema:['Pathologic Function']
# Types for Edema:['Pathologic Function']
# Types for Erythema:['Disease or Syndrome']
# Types for Muscle Rigidity:['Sign or Symptom']
# Types for Seizures:['Sign or Symptom']
# Types for Edema:['Pathologic Function']
# Types for Paresthesia:['Disease or Syndrome']
# Types for Tremor:['Sign or Symptom']
# Types for Hemorrhage:['Pathologic Function']
# Types for Contusions:['Injury or Poisoning']
# Types for Vomiting:['Sign or Symptom']
# Types for Eructation:['Sign or Symptom']
# Types for Heartburn:['Sign or Symptom']
# Types for Dyspepsia:['Sign or Symptom']
# Types for Pain:['Sign or Symptom']
# Types for Upset stomach:['Sign or Symptom']
# Types for Pain:['Sign or Symptom']
# Types for Epistaxis:['Pathologic Function']
# Types for Tinnitus:['Disease or Syndrome']
# Types for Derealization:['Mental or Behavioral Dysfunction']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Arthralgia:['Sign or Symptom']
# Types for Anorexia:['Disease or Syndrome']
# Types for Myalgia:['Sign or Symptom']
# Types for Muscle Cramp:['Sign or Symptom']
# Types for Myalgia:['Sign or Symptom']
# Types for Stiffness:['Sign or Symptom']
# Types for Pain:['Sign or Symptom']
# Types for Burning sensation:['Sign or Symptom']
# Types for Traumatic injection site:['Injury or Poisoning']
# Types for Pain:['Sign or Symptom']
# Types for Erythema:['Disease or Syndrome']
# Types for Vertigo:['Sign or Symptom']
# Types for Retinal Detachment:['Disease or Syndrome']
# Types for Trembling:['Sign or Symptom']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Agitation:['Sign or Symptom']
# Types for Burning sensation:['Sign or Symptom']
# Types for Pruritus:['Sign or Symptom']
# Types for Prickling sensation:['Sign or Symptom']
# Types for Chest Pain:['Sign or Symptom']
# Types for Discomfort:['Sign or Symptom']
# Types for Chills:['Sign or Symptom']
# Types for Cold sweat:['Sign or Symptom']
# Types for Confusion:['Mental or Behavioral Dysfunction']
# Types for Delirium:['Mental or Behavioral Dysfunction']
# Types for Diarrhea:['Sign or Symptom']
# Types for Dizziness:['Sign or Symptom']
# Types for Dizziness:['Sign or Symptom']
# Types for Syncope:['Sign or Symptom']
# Types for Lightheadedness:['Sign or Symptom']
# Types for Syncope:['Sign or Symptom']
# Types for Hallucinations:['Mental or Behavioral Dysfunction']
# Types for Urticaria:['Disease or Syndrome']
# Types for Pruritus:['Sign or Symptom']
# Types for Exanthema:['Sign or Symptom']
# Types for Lightheadedness:['Sign or Symptom']
# Types for Facial edema:['Pathologic Function']
# Types for Edema:['Pathologic Function']
# Types for Erythema:['Disease or Syndrome']
# Types for Muscle Rigidity:['Sign or Symptom']
# Types for Tremor:['Sign or Symptom']
# Types for Fatigue:['Sign or Symptom']
# Types for Asthenia:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Headache:['Sign or Symptom']
# Types for sour stomach:['Sign or Symptom']
# Types for Eructation:['Sign or Symptom']
# Types for Burning sensation:['Sign or Symptom']
# Types for Pain:['Sign or Symptom']
# Types for Traumatic injection site:['Injury or Poisoning']
# Types for Constipation:['Sign or Symptom']
# Types for Heartburn:['Sign or Symptom']
# Types for Dyspepsia:['Sign or Symptom']
# Types for Arthralgia:['Sign or Symptom']
# Types for Myalgia:['Sign or Symptom']
# Types for Muscle Cramp:['Sign or Symptom']
# Types for Myalgia:['Sign or Symptom']
# Types for Stiffness:['Sign or Symptom']
# Types for Vertigo:['Sign or Symptom']
# Types for Upset stomach:['Sign or Symptom']
# Types for Pain:['Sign or Symptom']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Generalized essential telangiectasia (disorder):['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Urticaria:['Disease or Syndrome']
# Types for Edema:['Pathologic Function']
# Types for Liver damage:['Pathologic Function']
# Types for Hemorrhage:['Pathologic Function']
# Types for Nausea:['Sign or Symptom']
# Types for Anorexia:['Disease or Syndrome']
# Types for Icterus:['Sign or Symptom']
# Types for Hemorrhage:['Pathologic Function']
# Types for Exanthema:['Sign or Symptom']
# Types for Erythema:['Disease or Syndrome']
# Types for Sunburn:['Injury or Poisoning']
# Types for Exanthema:['Sign or Symptom']
# Types for Myalgia:['Sign or Symptom']
# Types for Fever:['Sign or Symptom']
# Types for Hunger:['Sign or Symptom']
# Types for Communicable Diseases:['Disease or Syndrome']
# Types for Fever:['Sign or Symptom']
# Types for Night sweats:['Sign or Symptom']
# Types for Swollen Lymph Node:['Sign or Symptom']
# Types for Herpes Labialis:['Disease or Syndrome']
# Types for Coughing:['Sign or Symptom']
# Types for Wheezing:['Sign or Symptom']
# Types for Diarrhea:['Sign or Symptom']
# Types for Asthenia:['Sign or Symptom']
# Types for Edema:['Pathologic Function']
# Types for Goiter:['Disease or Syndrome']
# Types for Erectile dysfunction:['Disease or Syndrome']
# Types for Nausea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Diarrhea:['Sign or Symptom']
# Types for Abdominal Pain:['Sign or Symptom']
# Types for Exanthema:['Sign or Symptom']
# Types for Headache:['Sign or Symptom']
# Types for Fever:['Sign or Symptom']
# Types for Fatigue:['Sign or Symptom']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Generalized essential telangiectasia (disorder):['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Urticaria:['Disease or Syndrome']
# Types for Edema:['Pathologic Function']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Abdominal Pain:['Sign or Symptom']
# Types for Melena:['Pathologic Function']
# Types for Hemorrhage:['Pathologic Function']
# Types for Blue lips:['Sign or Symptom']
# Types for Burning sensation:['Sign or Symptom']
# Types for Pruritus:['Sign or Symptom']
# Types for Prickling sensation:['Sign or Symptom']
# Types for Chest Pain:['Sign or Symptom']
# Types for Chills:['Sign or Symptom']
# Types for Cold sweat:['Sign or Symptom']
# Types for Confusion:['Mental or Behavioral Dysfunction']
# Types for Constipation:['Sign or Symptom']
# Types for Hoarseness:['Sign or Symptom']
# Types for Coughing:['Sign or Symptom']
# Types for Coughing:['Sign or Symptom']
# Types for Diarrhea:['Sign or Symptom']
# Types for Dizziness:['Sign or Symptom']
# Types for Syncope:['Sign or Symptom']
# Types for Lightheadedness:['Sign or Symptom']
# Types for Fever:['Sign or Symptom']
# Types for Dry skin:['Sign or Symptom']
# Types for Edema:['Pathologic Function']
# Types for Discomfort:['Sign or Symptom']
# Types for Illness (finding):['Sign or Symptom']
# Types for Headache:['Sign or Symptom']
# Types for Urticaria:['Disease or Syndrome']
# Types for Pruritus:['Sign or Symptom']
# Types for Exanthema:['Sign or Symptom']
# Types for Hunger:['Sign or Symptom']
# Types for Dyspepsia:['Sign or Symptom']
# Types for Arthralgia:['Sign or Symptom']
# Types for Stiffness:['Sign or Symptom']
# Types for Edema:['Pathologic Function']
# Types for Anorexia:['Disease or Syndrome']
# Types for side pain:['Sign or Symptom']
# Types for Muscle Cramp:['Sign or Symptom']
# Types for Pain:['Sign or Symptom']
# Types for Nausea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Epistaxis:['Pathologic Function']
# Types for Paresthesia:['Disease or Syndrome']
# Types for Pain:['Sign or Symptom']
# Types for Asthenia:['Sign or Symptom']
# Types for Pain:['Sign or Symptom']
# Types for Pain:['Sign or Symptom']
# Types for Facial edema:['Pathologic Function']
# Types for Edema:['Pathologic Function']
# Types for Erythema:['Disease or Syndrome']
# Types for Sore to touch:['Sign or Symptom']
# Types for Seizures:['Sign or Symptom']
# Types for Cyst of eyelid:['Disease or Syndrome']
# Types for Pharyngitis:['Disease or Syndrome']
# Types for Oral Ulcer:['Disease or Syndrome']
# Types for Ulcer:['Pathologic Function']
# Types for Oral Ulcer:['Disease or Syndrome']
# Types for Edema:['Pathologic Function']
# Types for Pain:['Sign or Symptom']
# Types for Sore to touch:['Sign or Symptom']
# Types for Trembling:['Sign or Symptom']
# Types for Halitosis:['Sign or Symptom']
# Types for Hemorrhage:['Pathologic Function']
# Types for Contusions:['Injury or Poisoning']
# Types for Fatigue:['Sign or Symptom']
# Types for Asthenia:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Asthenia:['Sign or Symptom']
# Types for Muscle Cramp:['Sign or Symptom']
# Types for Alopecia:['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Spasm:['Sign or Symptom']
# Types for Erythema:['Disease or Syndrome']
# Types for Agitation:['Sign or Symptom']
# Types for Vertigo:['Sign or Symptom']
# Types for Sunburn:['Injury or Poisoning']
# Types for Asthenia:['Sign or Symptom']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Abdominal Pain:['Sign or Symptom']
# Types for Abdominal Pain:['Sign or Symptom']
# Types for Melena:['Pathologic Function']
# Types for Hemorrhage:['Pathologic Function']
# Types for Blue lips:['Sign or Symptom']
# Types for Burning sensation:['Sign or Symptom']
# Types for Pruritus:['Sign or Symptom']
# Types for Prickling sensation:['Sign or Symptom']
# Types for Chest Pain:['Sign or Symptom']
# Types for Chills:['Sign or Symptom']
# Types for Cold sweat:['Sign or Symptom']
# Types for Confusion:['Mental or Behavioral Dysfunction']
# Types for Constipation:['Sign or Symptom']
# Types for Hoarseness:['Sign or Symptom']
# Types for Coughing:['Sign or Symptom']
# Types for Coughing:['Sign or Symptom']
# Types for Diarrhea:['Sign or Symptom']
# Types for Wheezing:['Sign or Symptom']
# Types for Dizziness:['Sign or Symptom']
# Types for Syncope:['Sign or Symptom']
# Types for Lightheadedness:['Sign or Symptom']
# Types for Fever:['Sign or Symptom']
# Types for Dry skin:['Sign or Symptom']
# Types for Edema:['Pathologic Function']
# Types for Discomfort:['Sign or Symptom']
# Types for Illness (finding):['Sign or Symptom']
# Types for Fatigue:['Sign or Symptom']
# Types for Asthenia:['Sign or Symptom']
# Types for Headache:['Sign or Symptom']
# Types for Urticaria:['Disease or Syndrome']
# Types for Hunger:['Sign or Symptom']
# Types for Dyspepsia:['Sign or Symptom']
# Types for Pruritus:['Sign or Symptom']
# Types for Arthralgia:['Sign or Symptom']
# Types for Stiffness:['Sign or Symptom']
# Types for Edema:['Pathologic Function']
# Types for Anorexia:['Disease or Syndrome']
# Types for side pain:['Sign or Symptom']
# Types for Muscle Cramp:['Sign or Symptom']
# Types for Pain:['Sign or Symptom']
# Types for Nausea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Epistaxis:['Pathologic Function']
# Types for Paresthesia:['Disease or Syndrome']
# Types for Pain:['Sign or Symptom']
# Types for Asthenia:['Sign or Symptom']
# Types for Pain:['Sign or Symptom']
# Types for Pain:['Sign or Symptom']
# Types for Pain:['Sign or Symptom']
# Types for Facial edema:['Pathologic Function']
# Types for Edema:['Pathologic Function']
# Types for Exanthema:['Sign or Symptom']
# Types for Erythema:['Disease or Syndrome']
# Types for Sore to touch:['Sign or Symptom']
# Types for Pruritus:['Sign or Symptom']
# Types for Seizures:['Sign or Symptom']
# Types for Pharyngitis:['Disease or Syndrome']
# Types for Oral Ulcer:['Disease or Syndrome']
# Types for Ulcer:['Pathologic Function']
# Types for Oral Ulcer:['Disease or Syndrome']
# Types for Edema:['Pathologic Function']
# Types for Pain:['Sign or Symptom']
# Types for Sore to touch:['Sign or Symptom']
# Types for Trembling:['Sign or Symptom']
# Types for Halitosis:['Sign or Symptom']
# Types for Hemorrhage:['Pathologic Function']
# Types for Contusions:['Injury or Poisoning']
# Types for Fatigue:['Sign or Symptom']
# Types for Asthenia:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Asthenia:['Sign or Symptom']
# Types for Wheezing:['Sign or Symptom']
# Types for Muscle Cramp:['Sign or Symptom']
# Types for Alopecia:['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Spasm:['Sign or Symptom']
# Types for Purpura:['Disease or Syndrome']
# Types for Erythema:['Disease or Syndrome']
# Types for Agitation:['Sign or Symptom']
# Types for Vertigo:['Sign or Symptom']
# Types for Sunburn:['Injury or Poisoning']
# Types for Asthenia:['Sign or Symptom']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Generalized essential telangiectasia (disorder):['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Urticaria:['Disease or Syndrome']
# Types for Edema:['Pathologic Function']
# Types for Mood swings:['Mental or Behavioral Dysfunction']
# Types for Headache:['Sign or Symptom']
# Types for Dizziness:['Sign or Symptom']
# Types for Anxiety:['Mental or Behavioral Dysfunction']
# Types for Dizziness:['Sign or Symptom']
# Types for Dyssomnias:['Mental or Behavioral Dysfunction']
# Types for Sleeplessness:['Sign or Symptom']
# Types for Diarrhea:['Sign or Symptom']
# Types for Nervousness:['Sign or Symptom']
# Types for Agitation:['Sign or Symptom']
# Types for Anxiety:['Mental or Behavioral Dysfunction']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Generalized essential telangiectasia (disorder):['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Urticaria:['Disease or Syndrome']
# Types for Edema:['Pathologic Function']
# Types for Nervousness:['Sign or Symptom']
# Types for Dizziness:['Sign or Symptom']
# Types for Dyssomnias:['Mental or Behavioral Dysfunction']
# Types for Sleeplessness:['Sign or Symptom']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Diarrhea:['Sign or Symptom']
# Types for Dizziness:['Sign or Symptom']
# Types for Headache:['Sign or Symptom']
# Types for Nausea:['Sign or Symptom']
# Types for Stomach cramps (finding):['Sign or Symptom']
# Types for Fatigue:['Sign or Symptom']
# Types for Asthenia:['Sign or Symptom']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Generalized essential telangiectasia (disorder):['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Urticaria:['Disease or Syndrome']
# Types for Dyspnea:['Sign or Symptom']
# Types for Edema:['Pathologic Function']
# Types for Fever:['Sign or Symptom']
# Types for Fatigue:['Sign or Symptom']
# Types for Mood swings:['Mental or Behavioral Dysfunction']
# Types for Vomiting:['Sign or Symptom']
# Types for Diarrhea:['Sign or Symptom']
# Types for Anorexia:['Disease or Syndrome']
# Types for Confusion:['Mental or Behavioral Dysfunction']
# Types for Hemorrhage:['Pathologic Function']
# Types for Oral pain:['Sign or Symptom']
# Types for Seizures:['Sign or Symptom']
# Types for Alopecia:['Disease or Syndrome']
# Types for Osteoporosis:['Disease or Syndrome']
# Types for Hip Fractures:['Injury or Poisoning']
# Types for Fever:['Sign or Symptom']
# Types for Chills:['Sign or Symptom']
# Types for Chest Pain:['Sign or Symptom']
# Types for Dyspnea:['Sign or Symptom']
# Types for Vomiting:['Sign or Symptom']
# Types for Diarrhea:['Sign or Symptom']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Liver damage:['Pathologic Function']
# Types for Generalized essential telangiectasia (disorder):['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Urticaria:['Disease or Syndrome']
# Types for Edema:['Pathologic Function']
# Types for Pruritus:['Sign or Symptom']
# Types for Erythema:['Disease or Syndrome']
# Types for Edema:['Pathologic Function']
# Types for Oozing (Hemorrhage):['Pathologic Function']
# Types for Hyperglycemia:['Disease or Syndrome']
# Types for Pruritus:['Sign or Symptom']
# Types for Paresis:['Disease or Syndrome']
# Types for Nausea:['Sign or Symptom']
# Types for Diarrhea:['Sign or Symptom']
# Types for Fatigue:['Sign or Symptom']
# Types for Mood swings:['Mental or Behavioral Dysfunction']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Generalized essential telangiectasia (disorder):['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Urticaria:['Disease or Syndrome']
# Types for Edema:['Pathologic Function']
# Types for Pruritus:['Sign or Symptom']
# Types for Erythema:['Disease or Syndrome']
# Types for Edema:['Pathologic Function']
# Types for Oozing (Hemorrhage):['Pathologic Function']
# Types for Hyperglycemia:['Disease or Syndrome']
# Types for Pruritus:['Sign or Symptom']
# Types for Paresis:['Disease or Syndrome']
# Types for Nausea:['Sign or Symptom']
# Types for Diarrhea:['Sign or Symptom']
# Types for Fatigue:['Sign or Symptom']
# Types for Mood swings:['Mental or Behavioral Dysfunction']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Erythema:['Disease or Syndrome']
# Types for Sore to touch:['Sign or Symptom']
# Types for Pruritus:['Sign or Symptom']
# Types for Edema:['Pathologic Function']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Generalized essential telangiectasia (disorder):['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Urticaria:['Disease or Syndrome']
# Types for Edema:['Pathologic Function']
# Types for Erythema:['Disease or Syndrome']
# Types for Pruritus:['Sign or Symptom']
# Types for Burning sensation:['Sign or Symptom']
# Types for Stinging Sensation:['Sign or Symptom']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Generalized essential telangiectasia (disorder):['Disease or Syndrome']
# Types for Hypersensitivity:['Pathologic Function']
# Types for Urticaria:['Disease or Syndrome']
# Types for Edema:['Pathologic Function']
# Types for Erythema:['Disease or Syndrome']
# Types for Edema:['Pathologic Function']
# Types for Oozing (Hemorrhage):['Pathologic Function']
# Types for Hyperglycemia:['Disease or Syndrome']
# Types for Paresis:['Disease or Syndrome']
# Types for Nausea:['Sign or Symptom']
# Types for Diarrhea:['Sign or Symptom']
# Types for Fatigue:['Sign or Symptom']
# Types for Mood swings:['Mental or Behavioral Dysfunction']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Types for Confusion:['Mental or Behavioral Dysfunction']
# Types for Dizziness:['Sign or Symptom']
# Types for Syncope:['Sign or Symptom']
# Types for Lightheadedness:['Sign or Symptom']
# Types for Urticaria:['Disease or Syndrome']
# Types for Pruritus:['Sign or Symptom']
# Types for Exanthema:['Sign or Symptom']
# Types for Facial edema:['Pathologic Function']
# Types for Edema:['Pathologic Function']
# Types for Erythema:['Disease or Syndrome']
# Types for Fatigue:['Sign or Symptom']
# Types for Asthenia:['Sign or Symptom']
# Types for Warm skin:['Sign or Symptom']
# Types for Edema:['Pathologic Function']
# Types for Sore to touch:['Sign or Symptom']
# Types for Traumatic injection site:['Injury or Poisoning']
# Types for Digital Arthropathy-Brachydactyly, Familial:['Disease or Syndrome']
# Azulfidine: ['Contusions', 'Myalgia', 'Wheezing', 'Dry cough', 'Vomiting', 'Generalized essential telangiectasia (disorder)', 'Adverse reaction to drug', 'Eye Burns', 'Icterus', 'Upset stomach', 'Hypersensitivity', 'Pain of skin', 'Infection', 'Chest discomfort', 'Pharyngitis', 'Swollen Lymph Node', 'Hemorrhage', 'Headache', 'Chills', 'Asthenia', 'Digital Arthropathy-Brachydactyly, Familial', 'Abdominal Pain', 'Anorexia', 'Infections of musculoskeletal system', 'Oral Ulcer', 'Nausea', 'Cushingoid facies', 'Fever', 'Urticaria', 'Exanthema', 'Edema', 'Communicable Diseases']
# Abstral: ['Fatigue', 'Diarrhea', 'Sighing respiration', 'Vomiting', 'Generalized essential telangiectasia (disorder)', 'Muscular stiffness', 'Malignant Carcinoid Syndrome', 'Malnutrition', 'Hallucinations', 'Hypersensitivity', 'Dyspnea', 'Dizziness', 'Headache', 'Blue lips', 'Constipation', 'Asthenia', 'Digital Arthropathy-Brachydactyly, Familial', 'Agitation', 'Anorexia', 'Confusion', 'Nausea', 'Shallow breathing', 'Urticaria', 'Fever', 'Edema']
# Aczone: ['Back Pain', 'Erythema', 'Vomiting', 'Generalized essential telangiectasia (disorder)', 'Methemoglobinemia', 'Red blood cell disorder', 'Burning sensation', 'Hypersensitivity', 'Pain of skin', 'Pharyngitis', 'Pain', 'Asthenia', 'Digital Arthropathy-Brachydactyly, Familial', 'Confusion', 'Nausea', 'Urticaria', 'Septicemia', 'Fever', 'Exanthema', 'Edema']
# Adzynma: ['Pruritus', 'Nausea', 'Upper Respiratory Infections', 'Digital Arthropathy-Brachydactyly, Familial', 'Urticaria', 'Headache', 'Diarrhea', 'Lightheadedness', 'Hypersensitivity', 'Dyspnea', 'Migraine Disorders', 'Adverse effects', 'Exanthema', 'Dizziness', 'Vomiting', 'Abdominal Pain', 'Syncope', 'Chest Pain']
# Adzenys XR-ODT: ['Pruritus', 'Abnormal behavior', 'Tic disorder', 'Diarrhea', 'Muscular stiffness', 'Generalized essential telangiectasia (disorder)', 'Vomiting', 'Malignant Carcinoid Syndrome', 'Paranoia', 'Hallucinations', 'Anxiety', 'Hypersensitivity', 'Dyspnea', 'Sleep disturbances', 'Dizziness', 'Mood swings', 'HEART PROBLEM', 'sexual problem', 'Headache', 'Constipation', 'Pain', 'Digital Arthropathy-Brachydactyly, Familial', 'Abdominal Pain', 'Muscular fasciculation', 'Erectile dysfunction', 'Agitation', 'Anorexia', 'Nausea', 'Urticaria', 'Fever', 'Seizures', 'Edema', 'Nervousness']
# AfterPill: ['Fatigue', 'Nausea', 'Digital Arthropathy-Brachydactyly, Familial', 'Urticaria', 'Pregnancy, Tubal', 'Diarrhea', 'Headache', 'Hypersensitivity', 'Pain', 'Mastodynia', 'Generalized essential telangiectasia (disorder)', 'Edema', 'Sore to touch', 'Abdominal Pain', 'Vomiting', 'Dizziness']
# Aftate (Topical): ['Digital Arthropathy-Brachydactyly, Familial']
# Afstyla (recombinant): ['Pruritus', 'Cold sweat', 'Erythema', 'Diarrhea', 'Wheezing', 'Vomiting', 'Generalized essential telangiectasia (disorder)', 'Lightheadedness', 'Hypersensitivity', 'Dizziness', 'Hemorrhage', 'Headache', 'Chills', 'Asthenia', 'Digital Arthropathy-Brachydactyly, Familial', 'Arthralgia', 'Syncope', 'Nausea', 'Urticaria', 'Fever', 'Paresthesia', 'Chest tightness', 'Injection of therapeutic agent', 'Flushing', 'Exanthema', 'Edema', 'Chest Pain']
# Airsupra (inhalation): ['Fatigue', 'Contusions', 'Leg cramps', 'Bone pain', 'Cataract', 'Wheezing', 'Glaucoma', 'Vomiting', 'Generalized essential telangiectasia (disorder)', 'BODY ACHE', 'Poliosis', 'Hoarseness', 'Coughing', 'Lightheadedness', 'Hypersensitivity', 'Pharyngitis', 'HEART PROBLEM', 'Paresis', 'Hemorrhage', 'Hypertensive disease', 'Headache', 'Constipation', 'Chills', 'Digital Arthropathy-Brachydactyly, Familial', 'Arthralgia', 'Abdominal Pain', 'Anorexia', 'Oral Ulcer', 'Nausea', 'Urticaria', 'Fever', 'Paresthesia', 'Edema', 'Communicable Diseases']
# Airsupra: ['Pruritus', 'Fatigue', 'Spraying behavior', 'Erythema', 'Cataract', 'Wheezing', 'Air-Drying', 'Glaucoma', 'Vomiting', 'Adverse effects', 'Mycoses', 'Hoarseness', 'Coughing', 'Ifosfamide/Methotrexate/Procarbazine protocol', 'Dyspnea', 'Hypersensitivity', 'Molluscum Contagiosum', 'Infection', 'HEART PROBLEM', 'Cerebral artery atherosclerosis', 'Headache', 'Chills', 'Foreign Bodies', 'Pain', 'Wounds and Injuries', 'Asthenia', 'Digital Arthropathy-Brachydactyly, Familial', 'Tremor', 'Paradoxical bronchospasm', 'Nausea', 'Fever', 'Candidiasis', 'Adrenal gland hypofunction', 'Osteoporosis', 'Exanthema', 'Edema', 'Communicable Diseases', 'Chest Pain']
# Akynzeo for (injection): ['Fatigue', 'Nausea', 'Urticaria', 'Erythema', 'Upset stomach', 'Hallucinations', 'Diarrhea', 'Headache', 'Hypersensitivity', 'Constipation', 'Muscular stiffness', 'Generalized essential telangiectasia (disorder)', 'Edema', 'Vomiting', 'Digital Arthropathy-Brachydactyly, Familial', 'Agitation', 'Malignant Carcinoid Syndrome', 'Chest Pain']
# Alyq: ['Back Pain', 'Erythema', 'Myalgia', 'Tinnitus', 'Generalized essential telangiectasia (disorder)', 'Adverse effects', 'Myocardial Infarction', 'Upset stomach', 'Hypersensitivity', 'Dyspnea', 'Dizziness', 'Rhinorrhea', 'Sudden Visual Loss', 'Headache', 'Pain', 'Digital Arthropathy-Brachydactyly, Familial', 'Nausea', 'Urticaria', 'Tissue damage', 'Nasal congestion (finding)', 'Flushing', 'Edema', 'Chest Pain']
# Amzeeq: ['Pruritus', 'Fatigue', 'Contusions', 'Myalgia', 'Diarrhea', 'Generalized essential telangiectasia (disorder)', 'Influenza', 'Adverse reaction to drug', 'Eye Burns', 'Icterus', 'Hypersensitivity', 'Pain of skin', 'Dizziness', 'Pharyngitis', 'Swollen Lymph Node', 'Headache', 'Pain', 'Asthenia', 'Digital Arthropathy-Brachydactyly, Familial', 'Arthralgia', 'Abdominal Pain', 'Anorexia', 'Confusion', 'Fever', 'Urticaria', 'Exanthema', 'Edema', 'Chest Pain']
# Anzemet (Oral): ['Discomfort', 'Fatigue', 'Pruritus', 'Contusions', 'Erythema', 'Epistaxis', 'Diarrhea', 'Myalgia', 'Traumatic injection site', 'Tinnitus', 'Vomiting', 'Welts', 'Eructation', 'Muscle Rigidity', 'Retinal Detachment', 'Burning sensation', 'Upset stomach', 'Melena', 'Hallucinations', 'Lightheadedness', 'Mental Depression', 'Heartburn', 'Hypersensitivity', 'Facial edema', 'Sore to touch', 'Dizziness', 'Lethargy', 'Hemorrhage', 'Headache', 'Chills', 'Dyspepsia', 'Pain', 'Asthenia', 'Digital Arthropathy-Brachydactyly, Familial', 'Arthralgia', 'Delirium', 'Syncope', 'Muscular fasciculation', 'Agitation', 'Tremor', 'Anorexia', 'Confusion', 'Nausea', 'Purpura', 'Fever', 'Urticaria', 'Vertigo', 'Paresthesia', 'Muscle Cramp', 'Seizures', 'Trembling', 'Stiffness', 'Exanthema', 'Derealization', 'Edema', 'Chest Pain']
# Anzemet (Intravenous): ['Discomfort', 'Pruritus', 'Fatigue', 'Cold sweat', 'Erythema', 'Prickling sensation', 'Diarrhea', 'Myalgia', 'Traumatic injection site', 'Vomiting', 'Eructation', 'Muscle Rigidity', 'Burning sensation', 'Upset stomach', 'Hallucinations', 'Lightheadedness', 'Heartburn', 'Facial edema', 'Dizziness', 'sour stomach', 'Headache', 'Constipation', 'Chills', 'Dyspepsia', 'Pain', 'Asthenia', 'Digital Arthropathy-Brachydactyly, Familial', 'Arthralgia', 'Delirium', 'Syncope', 'Agitation', 'Tremor', 'Confusion', 'Urticaria', 'Vertigo', 'Muscle Cramp', 'Stiffness', 'Exanthema', 'Edema', 'Chest Pain']
# Aptivus: ['Fatigue', 'Erythema', 'Myalgia', 'Diarrhea', 'Wheezing', 'Liver damage', 'Vomiting', 'Generalized essential telangiectasia (disorder)', 'Icterus', 'Herpes Labialis', 'Goiter', 'Coughing', 'Hypersensitivity', 'Night sweats', 'Swollen Lymph Node', 'Hemorrhage', 'Sunburn', 'Headache', 'Hunger', 'Asthenia', 'Digital Arthropathy-Brachydactyly, Familial', 'Abdominal Pain', 'Erectile dysfunction', 'Anorexia', 'Nausea', 'Urticaria', 'Fever', 'Exanthema', 'Edema', 'Communicable Diseases']
# Aquoral: ['Urticaria', 'Hypersensitivity', 'Generalized essential telangiectasia (disorder)', 'Edema', 'Digital Arthropathy-Brachydactyly, Familial']
# Aquazide H (Oral): ['Discomfort', 'Pruritus', 'Fatigue', 'Cold sweat', 'Cyst of eyelid', 'Contusions', 'Erythema', 'Epistaxis', 'Prickling sensation', 'Diarrhea', 'Spasm', 'Vomiting', 'Burning sensation', 'Hoarseness', 'Melena', 'Coughing', 'Lightheadedness', 'Hypersensitivity', 'Facial edema', 'Sore to touch', 'Dizziness', 'Alopecia', 'Dry skin', 'Pharyngitis', 'Hemorrhage', 'Sunburn', 'Headache', 'Halitosis', 'Blue lips', 'Constipation', 'Chills', 'Hunger', 'Dyspepsia', 'Pain', 'Ulcer', 'Asthenia', 'Illness (finding)', 'Arthralgia', 'Abdominal Pain', 'Syncope', 'Digital Arthropathy-Brachydactyly, Familial', 'Agitation', 'Anorexia', 'side pain', 'Confusion', 'Nausea', 'Oral Ulcer', 'Fever', 'Urticaria', 'Vertigo', 'Muscle Cramp', 'Paresthesia', 'Seizures', 'Trembling', 'Stiffness', 'Exanthema', 'Edema', 'Chest Pain']
# Aquatensen (Oral): ['Discomfort', 'Pruritus', 'Fatigue', 'Cold sweat', 'Contusions', 'Erythema', 'Epistaxis', 'Prickling sensation', 'Diarrhea', 'Spasm', 'Wheezing', 'Vomiting', 'Burning sensation', 'Hoarseness', 'Melena', 'Coughing', 'Lightheadedness', 'Hypersensitivity', 'Facial edema', 'Sore to touch', 'Dizziness', 'Alopecia', 'Dry skin', 'Pharyngitis', 'Hemorrhage', 'Sunburn', 'Headache', 'Halitosis', 'Blue lips', 'Constipation', 'Chills', 'Hunger', 'Dyspepsia', 'Pain', 'Ulcer', 'Asthenia', 'Illness (finding)', 'Arthralgia', 'Abdominal Pain', 'Syncope', 'Digital Arthropathy-Brachydactyly, Familial', 'Agitation', 'Anorexia', 'side pain', 'Confusion', 'Nausea', 'Oral Ulcer', 'Purpura', 'Fever', 'Urticaria', 'Vertigo', 'Muscle Cramp', 'Paresthesia', 'Seizures', 'Trembling', 'Stiffness', 'Exanthema', 'Edema', 'Chest Pain']
# Aquatab DM: ['Digital Arthropathy-Brachydactyly, Familial', 'Sleeplessness', 'Urticaria', 'Headache', 'Diarrhea', 'Anxiety', 'Hypersensitivity', 'Dizziness', 'Generalized essential telangiectasia (disorder)', 'Edema', 'Dyssomnias', 'Nervousness', 'Mood swings', 'Agitation']
# Aquatab D: ['Sleeplessness', 'Urticaria', 'Hypersensitivity', 'Dizziness', 'Generalized essential telangiectasia (disorder)', 'Edema', 'Dyssomnias', 'Nervousness', 'Digital Arthropathy-Brachydactyly, Familial']
# Aquasol E (Oral): ['Fatigue', 'Nausea', 'Diarrhea', 'Headache', 'Asthenia', 'Dizziness', 'Stomach cramps (finding)', 'Digital Arthropathy-Brachydactyly, Familial']
# Aquasol A: ['Fatigue', 'Diarrhea', 'Liver damage', 'Vomiting', 'Generalized essential telangiectasia (disorder)', 'Hip Fractures', 'Hypersensitivity', 'Dyspnea', 'Alopecia', 'Mood swings', 'Oral pain', 'Hemorrhage', 'Chills', 'Digital Arthropathy-Brachydactyly, Familial', 'Anorexia', 'Confusion', 'Urticaria', 'Fever', 'Seizures', 'Osteoporosis', 'Edema', 'Chest Pain']
# Aquaphor Itch Relief Maximum Strength: ['Pruritus', 'Fatigue', 'Paresis', 'Nausea', 'Digital Arthropathy-Brachydactyly, Familial', 'Urticaria', 'Erythema', 'Diarrhea', 'Oozing (Hemorrhage)', 'Hypersensitivity', 'Hyperglycemia', 'Generalized essential telangiectasia (disorder)', 'Edema', 'Mood swings']
# Aquaphor Itch Relief: ['Pruritus', 'Fatigue', 'Paresis', 'Nausea', 'Digital Arthropathy-Brachydactyly, Familial', 'Urticaria', 'Erythema', 'Diarrhea', 'Oozing (Hemorrhage)', 'Hypersensitivity', 'Hyperglycemia', 'Generalized essential telangiectasia (disorder)', 'Edema', 'Mood swings']
# Aquaphor Healing: ['Pruritus', 'Erythema', 'Sore to touch', 'Edema', 'Digital Arthropathy-Brachydactyly, Familial']
# Aquaphilic with Urea: ['Pruritus', 'Urticaria', 'Burning sensation', 'Erythema', 'Hypersensitivity', 'Stinging Sensation', 'Generalized essential telangiectasia (disorder)', 'Edema', 'Digital Arthropathy-Brachydactyly, Familial']
# Aquanil HC: ['Fatigue', 'Paresis', 'Nausea', 'Digital Arthropathy-Brachydactyly, Familial', 'Urticaria', 'Erythema', 'Diarrhea', 'Oozing (Hemorrhage)', 'Hypersensitivity', 'Hyperglycemia', 'Generalized essential telangiectasia (disorder)', 'Edema', 'Mood swings']
# Aquamephyton (Injection): ['Pruritus', 'Confusion', 'Fatigue', 'Digital Arthropathy-Brachydactyly, Familial', 'Urticaria', 'Warm skin', 'Erythema', 'Lightheadedness', 'Asthenia', 'Facial edema', 'Traumatic injection site', 'Sore to touch', 'Dizziness', 'Exanthema', 'Edema', 'Syncope']

# %%
lst = ["Mirtazapine is an antidepressant. The way this medication works is still not fully understood. It is thought to positively affect communication between nerve cells in the central nervous system and/or restore chemical balance in the brain.", "Mirtazapine is used to treat major depressive disorder in adults.", "It is not known if mirtazapine is safe and effective for use to treat MDD in children."]

# %%
def process_melatonin_texts(text_list, nlp, linker):
    # Define relevant semantic types and their descriptions
    semantic_type_descriptions = {
        "T047": "Disease or Syndrome",
        "T184": "Sign or Symptom",
        "T046": "Pathologic Function",
        "T048": "Mental or Behavioral Dysfunction"
        # Add other relevant types as needed
    }

    for text in text_list:
        # Apply NLP to the text
        doc = nlp(text)

        # Iterate over the entities in the doc
        for entity in doc.ents:
            print("Name: ", entity.text)

            # Each entity is linked to UMLS with a score
            for umls_ent in entity._.kb_ents:
                umls_entity = linker.kb.cui_to_entity[umls_ent[0]]
                print(f"UMLS Entity: {umls_entity.canonical_name}, Score: {umls_ent[1]}")
                
                # Print semantic types of the UMLS entity
                semantic_types = umls_entity.types
                for type_code in semantic_types:
                    type_description = semantic_type_descriptions.get(type_code, "Unknown Type")
                    print(f"Semantic Type: {type_code}, Description: {type_description}")

process_melatonin_texts(lst, nlp, linker)
# Out:
# Name:  Mirtazapine
# UMLS Entity: mirtazapine, Score: 1.0
# Semantic Type: T109, Description: Unknown Type
# Semantic Type: T121, Description: Unknown Type
# Name:  antidepressant
# UMLS Entity: Antidepressive Agents, Score: 1.0
# Semantic Type: T121, Description: Unknown Type
# UMLS Entity: Antidepressant Measurement, Score: 0.8169975876808167
# Semantic Type: T059, Description: Unknown Type
# UMLS Entity: response to antidepressant, Score: 0.7954068779945374
# Semantic Type: T040, Description: Unknown Type
# UMLS Entity: Tricyclic Antidepressive Agents, Score: 0.7750267386436462
# Semantic Type: T121, Description: Unknown Type
# Name:  medication
# UMLS Entity: Pharmaceutical Preparations, Score: 1.0
# Semantic Type: T121, Description: Unknown Type
# UMLS Entity: medication - HL7 publishing domain, Score: 1.0
# Semantic Type: T170, Description: Unknown Type
# UMLS Entity: Medications, Score: 1.0
# Semantic Type: T170, Description: Unknown Type
# UMLS Entity: Medication Management, Score: 0.8655552864074707
# Semantic Type: T058, Description: Unknown Type
# UMLS Entity: Oral Medication, Score: 0.8461913466453552
# Semantic Type: T061, Description: Unknown Type
# Name:  communication
# UMLS Entity: Communication, Score: 1.0
# Semantic Type: T054, Description: Unknown Type
# UMLS Entity: Communications Media, Score: 0.8771328926086426
# Semantic Type: T170, Description: Unknown Type
# UMLS Entity: rnrx communication care, Score: 0.876935601234436
# Semantic Type: T058, Description: Unknown Type
# UMLS Entity: Cell Communication, Score: 0.8711560964584351
# Semantic Type: T043, Description: Unknown Type
# UMLS Entity: optical communication, Score: 0.837507963180542
# Semantic Type: T170, Description: Unknown Type
# Name:  nerve cells
# UMLS Entity: Neurons, Score: 1.0
# Semantic Type: T025, Description: Unknown Type
# UMLS Entity: Neural Stem Cells, Score: 0.8668623566627502
# Semantic Type: T025, Description: Unknown Type
# UMLS Entity: Cells, Score: 0.7270517349243164
# Semantic Type: T025, Description: Unknown Type
# Name:  central nervous system
# UMLS Entity: CENTRAL NERVOUS SYSTEM DIAGNOSTIC RADIOPHARMACEUTICALS, Score: 1.0
# Semantic Type: T130, Description: Unknown Type
# UMLS Entity: Central Nervous System, Score: 1.0
# Semantic Type: T022, Description: Unknown Type
# UMLS Entity: Central nervous system part, Score: 0.9127143621444702
# Semantic Type: T023, Description: Unknown Type
# UMLS Entity: Central Nervous System Agents, Score: 0.9120466709136963
# Semantic Type: T121, Description: Unknown Type
# UMLS Entity: Central Nervous System Cysts, Score: 0.9034298658370972
# Semantic Type: T047, Description: Disease or Syndrome
# Name:  restore
# UMLS Entity: Storage, Score: 0.7417030930519104
# Semantic Type: T169, Description: Unknown Type
# Name:  chemical
# UMLS Entity: Chemicals, Score: 1.0
# Semantic Type: T103, Description: Unknown Type
# UMLS Entity: Physical State, Score: 0.8036754727363586
# Semantic Type: T080, Description: Unknown Type
# UMLS Entity: Chemical procedure, Score: 0.800252377986908
# Semantic Type: T059, Description: Unknown Type
# UMLS Entity: chemical bond, Score: 0.797581136226654
# Semantic Type: T044, Description: Unknown Type
# UMLS Entity: Chemical Probe, Score: 0.7515454292297363
# Semantic Type: T120, Description: Unknown Type
# Name:  balance
# UMLS Entity: Equilibrium, Score: 1.0
# Semantic Type: T040, Description: Unknown Type
# UMLS Entity: Balance, device, Score: 1.0
# Semantic Type: T074, Description: Unknown Type
# UMLS Entity: Balanced - adjective, Score: 1.0
# Semantic Type: T169, Description: Unknown Type
# UMLS Entity: Ability to balance, Score: 1.0
# Semantic Type: T033, Description: Unknown Type
# UMLS Entity: Balance (substance), Score: 1.0
# Semantic Type: T109, Description: Unknown Type
# Semantic Type: T121, Description: Unknown Type
# Name:  brain
# UMLS Entity: Brain, Score: 0.9999998807907104
# Semantic Type: T023, Description: Unknown Type
# UMLS Entity: Head>Brain, Score: 0.9999998807907104
# Semantic Type: T023, Description: Unknown Type
# UMLS Entity: Malignant neoplasm of brain, Score: 0.8374496102333069
# Semantic Type: T191, Description: Unknown Type
# UMLS Entity: Cognitive Training, Score: 0.807202935218811
# Semantic Type: T061, Description: Unknown Type
# UMLS Entity: Transient Ischemic Attack, Score: 0.7935817241668701
# Semantic Type: T047, Description: Disease or Syndrome
# Name:  Mirtazapine
# UMLS Entity: mirtazapine, Score: 1.0
# Semantic Type: T109, Description: Unknown Type
# Semantic Type: T121, Description: Unknown Type
# Name:  treat
# UMLS Entity: Treatment intent, Score: 1.0
# Semantic Type: T169, Description: Unknown Type
# UMLS Entity: Treating, Score: 1.0
# Semantic Type: T169, Description: Unknown Type
# Name:  depressive disorder
# UMLS Entity: Depressive disorder, Score: 1.0
# Semantic Type: T048, Description: Mental or Behavioral Dysfunction
# UMLS Entity: Bipolar Disorder, Score: 0.9017273783683777
# Semantic Type: T048, Description: Mental or Behavioral Dysfunction
# UMLS Entity: Persistent depressive disorder, Score: 0.8195662498474121
# Semantic Type: T048, Description: Mental or Behavioral Dysfunction
# UMLS Entity: Unipolar Depression, Score: 0.8105269074440002
# Semantic Type: T048, Description: Mental or Behavioral Dysfunction
# UMLS Entity: Major Depressive Disorder, Score: 0.8105269074440002
# Semantic Type: T048, Description: Mental or Behavioral Dysfunction
# Name:  adults
# UMLS Entity: Adult, Score: 1.0
# Semantic Type: T100, Description: Unknown Type
# UMLS Entity: Adult Acute Myeloblastic Leukemia, Score: 0.8199233412742615
# Semantic Type: T191, Description: Unknown Type
# UMLS Entity: Elderly (population group), Score: 0.8121213912963867
# Semantic Type: T098, Description: Unknown Type
# UMLS Entity: Werner Syndrome, Score: 0.7875253558158875
# Semantic Type: T047, Description: Disease or Syndrome
# UMLS Entity: Young Adult, Score: 0.777332603931427
# Semantic Type: T100, Description: Unknown Type
# Name:  mirtazapine
# UMLS Entity: mirtazapine, Score: 1.0
# Semantic Type: T109, Description: Unknown Type
# Semantic Type: T121, Description: Unknown Type
# Name:  effective
# UMLS Entity: Effectiveness, Score: 1.0
# Semantic Type: T080, Description: Unknown Type
# UMLS Entity: Effective, Score: 1.0
# Semantic Type: T080, Description: Unknown Type
# UMLS Entity: Effect, Score: 0.8100234270095825
# Semantic Type: T080, Description: Unknown Type
# UMLS Entity: Effect, Appearance, Score: 0.8100234270095825
# Semantic Type: T080, Description: Unknown Type
# UMLS Entity: Effectiveness (finding), Score: 0.7950157523155212
# Semantic Type: T033, Description: Unknown Type
# Name:  treat
# UMLS Entity: Treatment intent, Score: 1.0
# Semantic Type: T169, Description: Unknown Type
# UMLS Entity: Treating, Score: 1.0
# Semantic Type: T169, Description: Unknown Type
# Name:  MDD
# UMLS Entity: Major Depressive Disorder, Score: 1.0
# Semantic Type: T048, Description: Mental or Behavioral Dysfunction
# UMLS Entity: Mal de debarquement, Score: 1.0
# Semantic Type: T047, Description: Disease or Syndrome
# Name:  children
# UMLS Entity: Child, Score: 1.0
# Semantic Type: T100, Description: Unknown Type
# UMLS Entity: Offspring, Score: 1.0
# Semantic Type: T099, Description: Unknown Type
# UMLS Entity: Reflux in Children, Score: 0.8715348243713379
# Semantic Type: T033, Description: Unknown Type
# UMLS Entity: Child, Exceptional, Score: 0.8608496785163879
# Semantic Type: T098, Description: Unknown Type
# UMLS Entity: Malignant Childhood Neoplasm, Score: 0.8135753870010376
# Semantic Type: T191, Description: Unknown Type

# %%
import requests

# Define the URL to retrieve the XML file
url = "https://dailymed.nlm.nih.gov/dailymed/services/v2/spls/1efe378e-fee1-4ae9-8ea5-0fe2265fe2d8.xml"

try:
    # Send an HTTP GET request to the URL
    response = requests.get(url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Define the file name to save the XML content
        file_name = "output2.xml"
        
        # Open the file in binary write mode and write the XML content
        with open(file_name, "wb") as file:
            file.write(response.content)
        
        print(f"XML content saved to {file_name}")
    else:
        # Handle the case where the request was not successful
        print(f"Request failed with status code {response.status_code}")
except requests.exceptions.RequestException as e:
    # Handle any exceptions that may occur during the request
    print(f"An error occurred: {e}")
# Out:
# XML content saved to output2.xml

# %%
import xml.etree.ElementTree as ET

# Parse the XML file
tree = ET.parse("output.xml")  # Replace "output.xml" with the actual file name

# Get the root element
root = tree.getroot()

# Define a list to store the extracted ingredient names
ingredient_names = []

# Find all <ingredientSubstance> elements
ingredient_substances = root.findall(".//ingredientSubstance")

# Iterate through <ingredientSubstance> elements and extract the <name> element
for ingredient_substance in ingredient_substances:
    name_element = ingredient_substance.find(".//name")
    if name_element is not None:
        ingredient_name = name_element.text
        ingredient_names.append(ingredient_name)

# Print the extracted ingredient names
for ingredient_name in ingredient_names:
    print("Ingredient Name:", ingredient_name)
